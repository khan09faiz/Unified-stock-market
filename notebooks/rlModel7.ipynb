# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import gym
from gym import spaces
import optuna

# Policy Network
class PolicyNetwork(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(PolicyNetwork, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(state_dim, 64),
            nn.ReLU(),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, action_dim)
        )
        self.log_std = nn.Parameter(torch.zeros(action_dim) + 0.15)

    def forward(self, state):
        mean = self.fc(state)
        std = torch.exp(self.log_std.clamp(min=-2, max=0.6))
        return mean, std

class ValueNetwork(nn.Module):
    def __init__(self, state_dim):
        super(ValueNetwork, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(state_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, 1)
        )

    def forward(self, state):
        return self.fc(state)

# Stock Trading Environment
class StockTradingEnv(gym.Env):
    def __init__(self, data, initial_capital=10000, stop_loss_pct=0.02, episode_length=300, trend_reward_coef=0.02, sentiment_reward_coef=0.01):
        super(StockTradingEnv, self).__init__()
        self.data = data.reset_index(drop=True)
        self.initial_capital = initial_capital
        self.stop_loss_pct = stop_loss_pct
        self.episode_length = episode_length
        self.trend_reward_coef = trend_reward_coef
        self.sentiment_reward_coef = sentiment_reward_coef
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(8,), dtype=np.float32)
        self.action_space = spaces.Box(low=-1, high=1, shape=(1,), dtype=np.float32)
        self.stop_loss_count = 0
        self.reward_history = []
        self.peak_net_worth = initial_capital

    def reset(self):
        self.current_step = np.random.randint(0, len(self.data) - self.episode_length)
        self.start_step = self.current_step
        self.net_worth = self.initial_capital
        self.position = 0.0
        self.prev_action = 0.0
        self.prev_total_assets = self.initial_capital
        self.stop_loss_count = 0
        self.reward_history = []
        self.peak_net_worth = self.initial_capital
        return self._get_observation()

    def _get_observation(self):
        start = max(0, self.current_step - 4)
        recent_data = self.data.iloc[start:self.current_step + 1]
        price_changes = recent_data['Average_Price_Change'].values
        if len(price_changes) < 5:
            price_changes = np.pad(price_changes, (5 - len(price_changes), 0), mode='constant')
        scaled_prices = price_changes / 0.15

        row = self.data.iloc[self.current_step]
        volatility_map = {'Low': 0, 'Medium': 1, 'High': 2}
        trend_map = {'Downtrend': -1, 'Stable': 0, 'Uptrend': 1}

        # Scale Sentiment_Score to [-1, 1]
        sentiment_scaled = np.clip(row['Sentiment_Score'], -2, 2) / 2

        return np.concatenate([
            scaled_prices,
            [volatility_map.get(row['Volatility_Level'], 1) / 2.0,
             sentiment_scaled,
             trend_map.get(row['Trend_Classification'], 0)]
        ], dtype=np.float32)

    def step(self, action):
        action = float(np.clip(action, -1, 1))
        row = self.data.iloc[self.current_step]
        current_price = row['End_Price']
        trend = {'Downtrend': -1, 'Stable': 0, 'Uptrend': 1}.get(row['Trend_Classification'], 0)
        delta_position = action - self.position

        transaction_cost = abs(delta_position) * current_price * 0.002
        if delta_position > 0:
            buy_cost = delta_position * current_price + transaction_cost
            if self.net_worth >= buy_cost:
                self.net_worth -= buy_cost
                self.position += delta_position
        elif delta_position < 0:
            sell_gain = -delta_position * current_price - transaction_cost
            self.net_worth += sell_gain
            self.position += delta_position

        self.position = np.clip(self.position, 0, 1)
        unrealized_value = self.position * current_price
        total_assets = self.net_worth + unrealized_value
        self.peak_net_worth = max(self.peak_net_worth, total_assets)

        # Smoothed and profit-locking reward function
        self.reward_history.append((total_assets - self.prev_total_assets) / self.initial_capital)
        if len(self.reward_history) > 10:
            smoothed_profit = np.mean(self.reward_history[-10:])
        else:
            smoothed_profit = np.mean(self.reward_history)
        volatility_map = {'Low': 0, 'Medium': 0.0005, 'High': 0.001}
        reward = smoothed_profit
        reward += self.trend_reward_coef * (action * trend)
        reward += self.sentiment_reward_coef * (action * row['Sentiment_Score'])
        reward -= 0.0005 * abs(delta_position)
        reward -= 0.00025 * action**2
        reward -= volatility_map.get(row['Volatility_Level'], 0.0005)
        if delta_position < 0 and total_assets < self.prev_total_assets:
            reward += 0.002 * abs(delta_position)
        if total_assets > self.peak_net_worth * 0.95 and delta_position < 0:
            reward += 0.003 * abs(delta_position)

        self.prev_total_assets = total_assets
        done = False

        if total_assets <= self.initial_capital * (1 - self.stop_loss_pct):
            done = True
            self.stop_loss_count += 1
            print(f"Stop-loss triggered at Episode {episode}, Step {self.current_step}, Net Worth: {total_assets:.2f}")

        self.prev_action = action
        self.current_step += 1
        if self.current_step >= len(self.data) - 1 or self.current_step - self.start_step >= self.episode_length:
            done = True

        next_state = self._get_observation() if not done else np.zeros_like(self._get_observation())
        return next_state, reward, done, {'net_worth': self.net_worth, 'position': self.position}

    def render(self):
        print(f"Step: {self.current_step}, Net Worth: {self.net_worth:.2f}, Position: {self.position:.2f}")

# PPO Agent
class PPOAgent:
    def __init__(self, state_dim, action_dim, lr, lr_value, gamma, eps_clip):
        self.policy = PolicyNetwork(state_dim, action_dim)
        self.value = ValueNetwork(state_dim)
        self.policy_old = PolicyNetwork(state_dim, action_dim)
        self.policy_old.load_state_dict(self.policy.state_dict())

        self.policy_optimizer = optim.Adam(self.policy.parameters(), lr=lr)
        self.value_optimizer = optim.Adam(self.value.parameters(), lr=lr_value)
        self.gamma = gamma
        self.eps_clip = eps_clip
        self.mse_loss = nn.MSELoss()
        self.lr_scheduler = optim.lr_scheduler.StepLR(self.policy_optimizer, step_size=100, gamma=0.97)

    def select_action(self, state):
        state = torch.FloatTensor(state).unsqueeze(0)
        mean, std = self.policy_old(state)
        dist = torch.distributions.Normal(mean, std)
        raw_action = dist.rsample()
        action = torch.tanh(raw_action.clamp(-3, 3))
        log_prob = dist.log_prob(raw_action).sum(dim=-1)
        return action.squeeze().detach().numpy(), log_prob.squeeze()

    def update(self, memory):
        states = torch.FloatTensor(np.array(memory['states']))
        actions = torch.FloatTensor(np.array(memory['actions']))
        old_log_probs = torch.stack(memory['log_probs']).detach()
        rewards = memory['rewards']

        returns = []
        discounted_sum = 0
        for reward in reversed(rewards):
            discounted_sum = reward + self.gamma * discounted_sum
            returns.insert(0, discounted_sum)
        returns = torch.FloatTensor(returns)

        values = self.value(states).squeeze().detach()
        advantages = returns - values
        advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-8)
        returns = (returns - returns.mean()) / (returns.std() + 1e-8)

        for _ in range(10):
            mean, std = self.policy(states)
            mean = torch.clamp(mean, -0.375, 0.375)
            dist = torch.distributions.Normal(mean, std)
            new_log_probs = dist.log_prob(actions).sum(dim=-1)
            entropy = dist.entropy().sum(dim=-1).mean()

            values = self.value(states).squeeze()
            ratio = torch.exp(new_log_probs - old_log_probs)
            surr1 = ratio * advantages
            surr2 = torch.clamp(ratio, 1 - self.eps_clip, 1 + self.eps_clip) * advantages

            policy_loss = -torch.min(surr1, surr2).mean()
            value_loss = self.mse_loss(values, returns)

            self.policy_optimizer.zero_grad()
            self.value_optimizer.zero_grad()
            total_loss = policy_loss + 0.5 * value_loss - 0.2 * entropy
            total_loss.backward()
            torch.nn.utils.clip_grad_norm_(self.policy.parameters(), 0.5)
            self.policy_optimizer.step()
            self.value_optimizer.step()

        self.policy.log_std.data = torch.clamp(self.policy.log_std.data - 0.011, min=-2, max=0.6)
        self.policy_old.load_state_dict(self.policy.state_dict())
        self.lr_scheduler.step()

def calculate_sharpe_ratio(returns, risk_free_rate=0.0):
    if len(returns) < 2:
        return 0.0
    excess_returns = np.array(returns) - risk_free_rate
    mean_return = np.mean(excess_returns)
    std_return = np.std(excess_returns)
    return mean_return / (std_return + 1e-8) if std_return > 0 else 0.0

def plot_net_worth(net_worths):
    plt.figure(figsize=(10, 5))
    plt.plot(net_worths, label='Net Worth Over Episodes', color='green')
    plt.xlabel('Episode')
    plt.ylabel('Net Worth ($)')
    plt.title('Net Worth Progression')
    plt.grid(True)
    plt.legend()
    plt.show()

def plot_cumulative_rewards(rewards):
    cumulative = np.cumsum(rewards)
    plt.figure(figsize=(10, 5))
    plt.plot(cumulative, label='Cumulative Rewards', color='orange')
    plt.xlabel('Episode')
    plt.ylabel('Total Reward')
    plt.title('Cumulative Rewards Over Time')
    plt.grid()
    plt.legend()
    plt.show()

def plot_action_distribution(actions):
    plt.figure(figsize=(7, 4))
    plt.hist(actions, bins=20, color='skyblue', edgecolor='black')
    plt.title('Action Distribution')
    plt.xlabel('Action Value')
    plt.ylabel('Frequency')
    plt.grid(axis='y')
    plt.show()

def preprocess_data(data):
    data['Average_Price_Change'] = (
        data['Average_Price_Change'] - data['Average_Price_Change'].mean()
    ) / data['Average_Price_Change'].std()
    data['Sentiment_Score'] = (
        data['Sentiment_Score'] - data['Sentiment_Score'].mean()
    ) / data['Sentiment_Score'].std()
    return data

# Objective function for Optuna
def objective(trial):
    # Suggest hyperparameters
    lr = trial.suggest_float('lr', 1e-5, 1e-2, log=True)
    lr_value = trial.suggest_float('lr_value', 1e-5, 1e-2, log=True)
    gamma = trial.suggest_float('gamma', 0.9, 0.99)
    eps_clip = trial.suggest_float('eps_clip', 0.1, 0.3)
    trend_reward_coef = trial.suggest_float('trend_reward_coef', 0.01, 0.1)
    sentiment_reward_coef = trial.suggest_float('sentiment_reward_coef', 0.01, 0.1)
    episode_length = trial.suggest_int('episode_length', 100, 500)

    # Load and preprocess data
    df = pd.read_csv("train_synthetic_stock_dataset2.csv")
    data = preprocess_data(df)
    env = StockTradingEnv(data, episode_length=episode_length, trend_reward_coef=trend_reward_coef, sentiment_reward_coef=sentiment_reward_coef)

    # Initialize agent
    state_dim = env.observation_space.shape[0]
    action_dim = env.action_space.shape[0]
    agent = PPOAgent(state_dim=state_dim, action_dim=action_dim, lr=lr, lr_value=lr_value, gamma=gamma, eps_clip=eps_clip)

    # Training loop
    memory = {'states': [], 'actions': [], 'log_probs': [], 'rewards': []}
    total_rewards = []
    net_worths = []
    episode_returns = []

    for episode in range(100):  # Reduced to 100 episodes for faster trials
        state = env.reset()
        done = False
        episode_reward = 0
        episode_net_worths = [env.net_worth]

        while not done:
            action, log_prob = agent.select_action(state)
            next_state, reward, done, info = env.step(action)

            memory['states'].append(state)
            memory['actions'].append(action)
            memory['log_probs'].append(log_prob)
            memory['rewards'].append(reward)
            state = next_state
            episode_reward += reward
            episode_net_worths.append(info['net_worth'])

        episode_return = (episode_net_worths[-1] - episode_net_worths[0]) / env.initial_capital
        episode_returns.append(episode_return)

        agent.update(memory)
        memory = {'states': [], 'actions': [], 'log_probs': [], 'rewards': []}
        total_rewards.append(episode_reward)
        net_worths.append(env.net_worth)

    # Objective is the final net worth
    final_net_worth = net_worths[-1]
    return final_net_worth

# Run Optuna study
if __name__ == "__main__":
    study = optuna.create_study(direction='maximize')
    study.optimize(objective, n_trials=50)  # Adjust n_trials as needed

    print("Best hyperparameters:", study.best_params)
    print("Best value (final net worth):", study.best_value)

    # Train with best params and save model
    best_params = study.best_params
    df = pd.read_csv("train_synthetic_stock_dataset2.csv")
    data = preprocess_data(df)
    env = StockTradingEnv(data, episode_length=best_params['episode_length'],
                         trend_reward_coef=best_params['trend_reward_coef'],
                         sentiment_reward_coef=best_params['sentiment_reward_coef'])

    state_dim = env.observation_space.shape[0]
    action_dim = env.action_space.shape[0]
    agent = PPOAgent(state_dim=state_dim, action_dim=action_dim, lr=best_params['lr'],
                     lr_value=best_params['lr_value'], gamma=best_params['gamma'],
                     eps_clip=best_params['eps_clip'])

    memory = {'states': [], 'actions': [], 'log_probs': [], 'rewards': []}
    total_rewards = []
    all_actions = []
    net_worths = []
    episode_returns = []

    for episode in range(1000):
        state = env.reset()
        done = False
        episode_reward = 0
        episode_net_worths = [env.net_worth]

        while not done:
            action, log_prob = agent.select_action(state)
            next_state, reward, done, info = env.step(action)

            memory['states'].append(state)
            memory['actions'].append(action)
            memory['log_probs'].append(log_prob)
            memory['rewards'].append(reward)
            all_actions.append(float(action))
            state = next_state
            episode_reward += reward
            episode_net_worths.append(info['net_worth'])

        episode_return = (episode_net_worths[-1] - episode_net_worths[0]) / env.initial_capital
        episode_returns.append(episode_return)

        agent.update(memory)
        memory = {'states': [], 'actions': [], 'log_probs': [], 'rewards': []}
        total_rewards.append(episode_reward)
        net_worths.append(env.net_worth)

        if (episode + 1) % 10 == 0:
            sharpe = calculate_sharpe_ratio(episode_returns[-100:])
            print(f"Episode {episode+1} | Total Reward: {episode_reward:.2f} | "
                  f"Net Worth: {env.net_worth:.2f} | "
                  f"Action Mean: {np.mean(all_actions[-100:]):.2f}, Std: {np.std(all_actions[-100:]):.2f} | "
                  f"Sharpe Ratio: {sharpe:.3f}")
        else:
            print(f"Episode {episode+1} | Total Reward: {episode_reward:.2f} | "
                  f"Net Worth: {env.net_worth:.2f} | "
                  f"Action Mean: {np.mean(all_actions[-100:]):.2f}, Std: {np.std(all_actions[-100:]):.2f}")

    torch.save(agent.policy.state_dict(), 'policy_weights.pth')
    torch.save(agent.value.state_dict(), 'value_weights.pth')

    plot_net_worth(net_worths)
    plot_cumulative_rewards(total_rewards)
    plot_action_distribution(all_actions)
# Out:
# [I 2025-04-21 01:17:43,018] A new study created in memory with name: no-name-f2db22f5-72e4-4532-9172-b61a035683f3
# [I 2025-04-21 01:18:16,726] Trial 0 finished with value: 18490.714929057413 and parameters: {'lr': 0.0004273659976539842, 'lr_value': 0.0002260008030135757, 'gamma': 0.9430949993425266, 'eps_clip': 0.1571472061938486, 'trend_reward_coef': 0.02234524111693494, 'sentiment_reward_coef': 0.01064137127769583, 'episode_length': 344}. Best is trial 0 with value: 18490.714929057413.
# [I 2025-04-21 01:18:52,479] Trial 1 finished with value: 25519.998396247596 and parameters: {'lr': 2.1542351506080138e-05, 'lr_value': 0.0016956776049638523, 'gamma': 0.9821512707752985, 'eps_clip': 0.16056442356836953, 'trend_reward_coef': 0.08584372248076472, 'sentiment_reward_coef': 0.015679749327170398, 'episode_length': 394}. Best is trial 1 with value: 25519.998396247596.
# [I 2025-04-21 01:19:05,103] Trial 2 finished with value: 18614.232299522035 and parameters: {'lr': 0.004428009186300271, 'lr_value': 0.003265767446114929, 'gamma': 0.9864546489288193, 'eps_clip': 0.12154989646471853, 'trend_reward_coef': 0.07752553425553023, 'sentiment_reward_coef': 0.07505891462194614, 'episode_length': 105}. Best is trial 1 with value: 25519.998396247596.
# [I 2025-04-21 01:19:29,702] Trial 3 finished with value: 21354.46661686134 and parameters: {'lr': 0.003668681893432584, 'lr_value': 0.00013784978189957864, 'gamma': 0.9243313707803534, 'eps_clip': 0.1577469487990503, 'trend_reward_coef': 0.06678107197016703, 'sentiment_reward_coef': 0.056245391855565284, 'episode_length': 254}. Best is trial 1 with value: 25519.998396247596.
# [I 2025-04-21 01:20:00,470] Trial 4 finished with value: 14144.909362325252 and parameters: {'lr': 2.993526725766199e-05, 'lr_value': 6.576003153574126e-05, 'gamma': 0.9172823801905288, 'eps_clip': 0.2542943783055589, 'trend_reward_coef': 0.09163692707396394, 'sentiment_reward_coef': 0.06908474215385725, 'episode_length': 344}. Best is trial 1 with value: 25519.998396247596.
# [I 2025-04-21 01:20:26,605] Trial 5 finished with value: 12425.527281416815 and parameters: {'lr': 7.563395308176519e-05, 'lr_value': 0.00413717845634434, 'gamma': 0.9353467971235562, 'eps_clip': 0.186903532867639, 'trend_reward_coef': 0.09294843472167842, 'sentiment_reward_coef': 0.08263135420510544, 'episode_length': 266}. Best is trial 1 with value: 25519.998396247596.
# [I 2025-04-21 01:20:59,998] Trial 6 finished with value: 18450.15419148972 and parameters: {'lr': 0.00013721606058079153, 'lr_value': 0.00011647571576142417, 'gamma': 0.9522621685175897, 'eps_clip': 0.13798304353473212, 'trend_reward_coef': 0.055415474924749034, 'sentiment_reward_coef': 0.03949350129886366, 'episode_length': 378}. Best is trial 1 with value: 25519.998396247596.
# [I 2025-04-21 01:21:21,991] Trial 7 finished with value: 20654.80913484876 and parameters: {'lr': 0.0005604678888948713, 'lr_value': 0.00020694054766277214, 'gamma': 0.9770295324558393, 'eps_clip': 0.12580145097959092, 'trend_reward_coef': 0.08762133626780844, 'sentiment_reward_coef': 0.043344915381071075, 'episode_length': 221}. Best is trial 1 with value: 25519.998396247596.
# [I 2025-04-21 01:21:46,498] Trial 8 finished with value: 12323.260779486523 and parameters: {'lr': 0.0013535058928382036, 'lr_value': 9.131574891050806e-05, 'gamma': 0.9434722440867156, 'eps_clip': 0.1436990252222681, 'trend_reward_coef': 0.0883368756681794, 'sentiment_reward_coef': 0.09376106364322585, 'episode_length': 254}. Best is trial 1 with value: 25519.998396247596.
# [I 2025-04-21 01:22:32,004] Trial 9 finished with value: 21568.92165754886 and parameters: {'lr': 0.00013610182766141907, 'lr_value': 0.006558745584490878, 'gamma': 0.9297294857494951, 'eps_clip': 0.21586726209439164, 'trend_reward_coef': 0.0654446426360346, 'sentiment_reward_coef': 0.03982546952215074, 'episode_length': 466}. Best is trial 1 with value: 25519.998396247596.
# [I 2025-04-21 01:23:22,797] Trial 10 finished with value: 22234.393740953277 and parameters: {'lr': 1.6061092900445286e-05, 'lr_value': 0.0011140139281324124, 'gamma': 0.9005394472680679, 'eps_clip': 0.2818693663825878, 'trend_reward_coef': 0.032116321667202026, 'sentiment_reward_coef': 0.011015412332584539, 'episode_length': 500}. Best is trial 1 with value: 25519.998396247596.
# [I 2025-04-21 01:24:14,304] Trial 11 finished with value: 17336.102724551856 and parameters: {'lr': 1.2581386807564715e-05, 'lr_value': 0.0010514612359495002, 'gamma': 0.9682027674026441, 'eps_clip': 0.293194977988039, 'trend_reward_coef': 0.026758204121859534, 'sentiment_reward_coef': 0.014029446056083836, 'episode_length': 499}. Best is trial 1 with value: 25519.998396247596.
# [I 2025-04-21 01:24:57,482] Trial 12 finished with value: 14850.856333083633 and parameters: {'lr': 1.1310505372244619e-05, 'lr_value': 1.0719575488463619e-05, 'gamma': 0.9018282248604416, 'eps_clip': 0.21821489781748046, 'trend_reward_coef': 0.03925319468014253, 'sentiment_reward_coef': 0.02463261631745462, 'episode_length': 426}. Best is trial 1 with value: 25519.998396247596.
# [I 2025-04-21 01:25:37,888] Trial 13 finished with value: 15233.702301869416 and parameters: {'lr': 3.956063816942327e-05, 'lr_value': 0.001000710826580066, 'gamma': 0.96271144223468, 'eps_clip': 0.29233122303312514, 'trend_reward_coef': 0.040777933261632496, 'sentiment_reward_coef': 0.025826260821418614, 'episode_length': 419}. Best is trial 1 with value: 25519.998396247596.
# [I 2025-04-21 01:26:24,789] Trial 14 finished with value: 20634.78296753747 and parameters: {'lr': 2.868005726098326e-05, 'lr_value': 0.0011470059359975657, 'gamma': 0.902905253804126, 'eps_clip': 0.2546934161415577, 'trend_reward_coef': 0.014699811606657044, 'sentiment_reward_coef': 0.024348393438147417, 'episode_length': 498}. Best is trial 1 with value: 25519.998396247596.
# [I 2025-04-21 01:27:08,588] Trial 15 finished with value: 18769.47491276379 and parameters: {'lr': 1.290721470610267e-05, 'lr_value': 0.0006234488224928653, 'gamma': 0.9146762494269085, 'eps_clip': 0.10224569988685929, 'trend_reward_coef': 0.04501835370704531, 'sentiment_reward_coef': 0.0535604632398856, 'episode_length': 422}. Best is trial 1 with value: 25519.998396247596.
# [I 2025-04-21 01:27:46,943] Trial 16 finished with value: 12897.053740866631 and parameters: {'lr': 6.646982316647372e-05, 'lr_value': 0.002471429937593637, 'gamma': 0.986983303673897, 'eps_clip': 0.1835644494454811, 'trend_reward_coef': 0.03018657665236609, 'sentiment_reward_coef': 0.01790896608409103, 'episode_length': 377}. Best is trial 1 with value: 25519.998396247596.
# [I 2025-04-21 01:28:28,902] Trial 17 finished with value: 17137.781500052653 and parameters: {'lr': 0.0001630982563477488, 'lr_value': 0.0005024152322999196, 'gamma': 0.9555949323197258, 'eps_clip': 0.24817997326127497, 'trend_reward_coef': 0.010221022659041117, 'sentiment_reward_coef': 0.030179625716169715, 'episode_length': 454}. Best is trial 1 with value: 25519.998396247596.
# [I 2025-04-21 01:28:47,496] Trial 18 finished with value: 12601.65164009042 and parameters: {'lr': 2.3356629330318684e-05, 'lr_value': 0.0019194469222591048, 'gamma': 0.974057848366899, 'eps_clip': 0.2288364130053653, 'trend_reward_coef': 0.05241251871289575, 'sentiment_reward_coef': 0.032335889997735234, 'episode_length': 173}. Best is trial 1 with value: 25519.998396247596.
# [I 2025-04-21 01:29:18,413] Trial 19 finished with value: 14280.513271164698 and parameters: {'lr': 5.9526234782130056e-05, 'lr_value': 4.348553301667704e-05, 'gamma': 0.9113508841449721, 'eps_clip': 0.17998371204055816, 'trend_reward_coef': 0.0740821299956275, 'sentiment_reward_coef': 0.05288231320624319, 'episode_length': 309}. Best is trial 1 with value: 25519.998396247596.
# [I 2025-04-21 01:29:53,443] Trial 20 finished with value: 19613.681754669768 and parameters: {'lr': 0.001139593701032402, 'lr_value': 0.008425460803785796, 'gamma': 0.9543071687434894, 'eps_clip': 0.2660373145738689, 'trend_reward_coef': 0.05665809037108427, 'sentiment_reward_coef': 0.010132749043435632, 'episode_length': 382}. Best is trial 1 with value: 25519.998396247596.
# [I 2025-04-21 01:30:35,558] Trial 21 finished with value: 10309.152974682045 and parameters: {'lr': 0.00015998842719802163, 'lr_value': 0.009120080966652485, 'gamma': 0.9301483914882742, 'eps_clip': 0.21645955159143307, 'trend_reward_coef': 0.06729875592020389, 'sentiment_reward_coef': 0.04023581605478628, 'episode_length': 464}. Best is trial 1 with value: 25519.998396247596.
# [I 2025-04-21 01:31:19,067] Trial 22 finished with value: 31019.5829465749 and parameters: {'lr': 2.1884106427779762e-05, 'lr_value': 0.004693321396436931, 'gamma': 0.9244490367146672, 'eps_clip': 0.20199470755989785, 'trend_reward_coef': 0.06485861948998352, 'sentiment_reward_coef': 0.01807113070119221, 'episode_length': 464}. Best is trial 22 with value: 31019.5829465749.
# [I 2025-04-21 01:32:04,126] Trial 23 finished with value: 13278.953626072642 and parameters: {'lr': 1.5882011412489512e-05, 'lr_value': 0.0014681420893491058, 'gamma': 0.9089635006905391, 'eps_clip': 0.162063487804041, 'trend_reward_coef': 0.07865706664252092, 'sentiment_reward_coef': 0.016834846701409743, 'episode_length': 444}. Best is trial 22 with value: 31019.5829465749.
# [I 2025-04-21 01:32:51,952] Trial 24 finished with value: 31633.58500214608 and parameters: {'lr': 2.1064149850396886e-05, 'lr_value': 0.0043208600644204275, 'gamma': 0.9211145698429801, 'eps_clip': 0.2741029272363243, 'trend_reward_coef': 0.033195948680768486, 'sentiment_reward_coef': 0.020948329277689862, 'episode_length': 500}. Best is trial 24 with value: 31633.58500214608.
# [I 2025-04-21 01:33:35,602] Trial 25 finished with value: 16388.972537788744 and parameters: {'lr': 5.059763806176451e-05, 'lr_value': 0.004460737330297314, 'gamma': 0.9219677407243415, 'eps_clip': 0.20182366527605142, 'trend_reward_coef': 0.04896062046367066, 'sentiment_reward_coef': 0.020898547878965855, 'episode_length': 398}. Best is trial 24 with value: 31633.58500214608.
# [I 2025-04-21 01:34:16,414] Trial 26 finished with value: 21058.67625591933 and parameters: {'lr': 2.154626811770869e-05, 'lr_value': 0.004847756963726433, 'gamma': 0.9375912748658105, 'eps_clip': 0.1996423394194776, 'trend_reward_coef': 0.09720206401509743, 'sentiment_reward_coef': 0.03371486194828663, 'episode_length': 470}. Best is trial 24 with value: 31633.58500214608.
# [I 2025-04-21 01:34:47,274] Trial 27 finished with value: 19425.00364510095 and parameters: {'lr': 8.266068042108334e-05, 'lr_value': 0.0022984186487881235, 'gamma': 0.9230064491074247, 'eps_clip': 0.2362311641239103, 'trend_reward_coef': 0.06089375145031545, 'sentiment_reward_coef': 0.029973132953289003, 'episode_length': 353}. Best is trial 24 with value: 31633.58500214608.
# [I 2025-04-21 01:35:24,323] Trial 28 finished with value: 12154.036383521456 and parameters: {'lr': 0.0002892672636166542, 'lr_value': 0.000538012393577708, 'gamma': 0.9320806405415891, 'eps_clip': 0.17443214514367844, 'trend_reward_coef': 0.07952893421226795, 'sentiment_reward_coef': 0.017591752771540074, 'episode_length': 408}. Best is trial 24 with value: 31633.58500214608.
# [I 2025-04-21 01:35:52,835] Trial 29 finished with value: 15558.334123165692 and parameters: {'lr': 3.5290673317987366e-05, 'lr_value': 0.0002919531279367831, 'gamma': 0.9411806907412997, 'eps_clip': 0.2784381557391159, 'trend_reward_coef': 0.08387197569053093, 'sentiment_reward_coef': 0.06472829817866832, 'episode_length': 310}. Best is trial 24 with value: 31633.58500214608.
# [I 2025-04-21 01:36:33,654] Trial 30 finished with value: 19133.27958272733 and parameters: {'lr': 0.00029714373989216114, 'lr_value': 0.0029674753258880997, 'gamma': 0.9501021542874678, 'eps_clip': 0.16884431436766978, 'trend_reward_coef': 0.01958057181795808, 'sentiment_reward_coef': 0.047961071255979246, 'episode_length': 444}. Best is trial 24 with value: 31633.58500214608.
# [I 2025-04-21 01:37:19,639] Trial 31 finished with value: 37183.74307522096 and parameters: {'lr': 1.956029979319333e-05, 'lr_value': 0.0016506597431062509, 'gamma': 0.90665608135886, 'eps_clip': 0.27837635268992883, 'trend_reward_coef': 0.03189068222632714, 'sentiment_reward_coef': 0.011398054193778373, 'episode_length': 487}. Best is trial 31 with value: 37183.74307522096.
# [I 2025-04-21 01:38:02,297] Trial 32 finished with value: 27544.99781505708 and parameters: {'lr': 2.0889653209559396e-05, 'lr_value': 0.0064623986325588615, 'gamma': 0.9093646090671218, 'eps_clip': 0.26618471419310913, 'trend_reward_coef': 0.03543466083134822, 'sentiment_reward_coef': 0.020996907895283065, 'episode_length': 477}. Best is trial 31 with value: 37183.74307522096.
# [I 2025-04-21 01:38:45,842] Trial 33 finished with value: 22367.9012936871 and parameters: {'lr': 1.0549924887545404e-05, 'lr_value': 0.0061763142315122595, 'gamma': 0.9080223529512516, 'eps_clip': 0.26846380782908197, 'trend_reward_coef': 0.03398483995352919, 'sentiment_reward_coef': 0.023054215096447082, 'episode_length': 476}. Best is trial 31 with value: 37183.74307522096.
# [I 2025-04-21 01:39:36,246] Trial 34 finished with value: 25337.8939396172 and parameters: {'lr': 0.00816376113289984, 'lr_value': 0.009912985697895288, 'gamma': 0.9175385754319706, 'eps_clip': 0.29806972475413823, 'trend_reward_coef': 0.02444509109581508, 'sentiment_reward_coef': 0.01417643636368536, 'episode_length': 477}. Best is trial 31 with value: 37183.74307522096.
# [I 2025-04-21 01:40:17,560] Trial 35 finished with value: 18921.44933374565 and parameters: {'lr': 4.384286772175915e-05, 'lr_value': 0.003625994059051744, 'gamma': 0.9073626672445443, 'eps_clip': 0.2714939866796226, 'trend_reward_coef': 0.03976415573828006, 'sentiment_reward_coef': 0.020905049541225892, 'episode_length': 440}. Best is trial 31 with value: 37183.74307522096.
# [I 2025-04-21 01:41:04,983] Trial 36 finished with value: 16930.69755595897 and parameters: {'lr': 2.0963225737734026e-05, 'lr_value': 0.006064575682937061, 'gamma': 0.9190500078752211, 'eps_clip': 0.2484343896853892, 'trend_reward_coef': 0.018668018000586435, 'sentiment_reward_coef': 0.02768509846967319, 'episode_length': 484}. Best is trial 31 with value: 37183.74307522096.
# [I 2025-04-21 01:41:23,556] Trial 37 finished with value: 14660.915122413864 and parameters: {'lr': 1.8196831309218058e-05, 'lr_value': 0.0035359716910193443, 'gamma': 0.9259747710205432, 'eps_clip': 0.28351008949850187, 'trend_reward_coef': 0.046333822869673934, 'sentiment_reward_coef': 0.036641946838455855, 'episode_length': 170}. Best is trial 31 with value: 37183.74307522096.
# [I 2025-04-21 01:42:03,772] Trial 38 finished with value: 21413.28589850414 and parameters: {'lr': 0.00010021462978751505, 'lr_value': 0.0019135178923757024, 'gamma': 0.9137282122583396, 'eps_clip': 0.26015560478783817, 'trend_reward_coef': 0.033180044370744725, 'sentiment_reward_coef': 0.012599117012752077, 'episode_length': 445}. Best is trial 31 with value: 37183.74307522096.
# [I 2025-04-21 01:42:47,562] Trial 39 finished with value: 39839.05600086466 and parameters: {'lr': 3.127933318938705e-05, 'lr_value': 0.0007515280080708703, 'gamma': 0.9066823409297079, 'eps_clip': 0.23133384940767956, 'trend_reward_coef': 0.03627153671645549, 'sentiment_reward_coef': 0.045494502510190445, 'episode_length': 482}. Best is trial 39 with value: 39839.05600086466.
# [I 2025-04-21 01:43:00,623] Trial 40 finished with value: 13143.790274458845 and parameters: {'lr': 3.2385698673376006e-05, 'lr_value': 0.0007815405754500444, 'gamma': 0.9262665086296038, 'eps_clip': 0.23328893898902098, 'trend_reward_coef': 0.027532077149576735, 'sentiment_reward_coef': 0.0661452395629784, 'episode_length': 101}. Best is trial 39 with value: 39839.05600086466.
# [I 2025-04-21 01:43:43,715] Trial 41 finished with value: 27416.810243375134 and parameters: {'lr': 2.1343523436648103e-05, 'lr_value': 0.0014957326399029323, 'gamma': 0.9056201478659417, 'eps_clip': 0.23846002984218698, 'trend_reward_coef': 0.03614437962610606, 'sentiment_reward_coef': 0.04505065454645868, 'episode_length': 484}. Best is trial 39 with value: 39839.05600086466.
# [I 2025-04-21 01:44:26,104] Trial 42 finished with value: 13201.322396673855 and parameters: {'lr': 2.866727175114177e-05, 'lr_value': 0.0003971263693031893, 'gamma': 0.9133477716724251, 'eps_clip': 0.2002034509251083, 'trend_reward_coef': 0.0444105131230114, 'sentiment_reward_coef': 0.08721768359199195, 'episode_length': 461}. Best is trial 39 with value: 39839.05600086466.
# [I 2025-04-21 01:45:10,086] Trial 43 finished with value: 16427.342987135133 and parameters: {'lr': 4.566676714455992e-05, 'lr_value': 0.002456305289499198, 'gamma': 0.9189588710295014, 'eps_clip': 0.27932281595849806, 'trend_reward_coef': 0.02254847637894824, 'sentiment_reward_coef': 0.05871827245548327, 'episode_length': 495}. Best is trial 39 with value: 39839.05600086466.
# [I 2025-04-21 01:45:51,053] Trial 44 finished with value: 21854.586349337005 and parameters: {'lr': 1.620882973762355e-05, 'lr_value': 0.00525698094588138, 'gamma': 0.9057279296933559, 'eps_clip': 0.24746378320420442, 'trend_reward_coef': 0.03692262478299288, 'sentiment_reward_coef': 0.0190710368004674, 'episode_length': 461}. Best is trial 39 with value: 39839.05600086466.
# [I 2025-04-21 01:46:30,661] Trial 45 finished with value: 17821.12817433759 and parameters: {'lr': 0.00010727075664107362, 'lr_value': 0.003216670771489267, 'gamma': 0.9114518635962314, 'eps_clip': 0.2583783017615893, 'trend_reward_coef': 0.07127821408166678, 'sentiment_reward_coef': 0.07977869465954798, 'episode_length': 431}. Best is trial 39 with value: 39839.05600086466.
# [I 2025-04-21 01:47:06,343] Trial 46 finished with value: 17737.16153311414 and parameters: {'lr': 1.0265256375728179e-05, 'lr_value': 0.0014333538491695947, 'gamma': 0.9016456643629466, 'eps_clip': 0.22426258590684062, 'trend_reward_coef': 0.02894760646063094, 'sentiment_reward_coef': 0.03597576143181714, 'episode_length': 360}. Best is trial 39 with value: 39839.05600086466.
# [I 2025-04-21 01:47:34,172] Trial 47 finished with value: 17813.77801277019 and parameters: {'lr': 2.850914963606056e-05, 'lr_value': 0.007401477300906845, 'gamma': 0.9161358090461991, 'eps_clip': 0.208384580976532, 'trend_reward_coef': 0.060950270778194496, 'sentiment_reward_coef': 0.01000121813538302, 'episode_length': 279}. Best is trial 39 with value: 39839.05600086466.
# [I 2025-04-21 01:48:15,642] Trial 48 finished with value: 16775.48649912244 and parameters: {'lr': 1.4959090664446579e-05, 'lr_value': 0.0007584164466273489, 'gamma': 0.9209415767622003, 'eps_clip': 0.28842047259746395, 'trend_reward_coef': 0.05003014888095056, 'sentiment_reward_coef': 0.027945380924562554, 'episode_length': 412}. Best is trial 39 with value: 39839.05600086466.
# [I 2025-04-21 01:48:58,344] Trial 49 finished with value: 48291.781432057585 and parameters: {'lr': 0.00046732797764326226, 'lr_value': 0.00022192870026771044, 'gamma': 0.9038702302176629, 'eps_clip': 0.2449968231409991, 'trend_reward_coef': 0.044391238078361046, 'sentiment_reward_coef': 0.01553354729142637, 'episode_length': 486}. Best is trial 49 with value: 48291.781432057585.
# Best hyperparameters: {'lr': 0.00046732797764326226, 'lr_value': 0.00022192870026771044, 'gamma': 0.9038702302176629, 'eps_clip': 0.2449968231409991, 'trend_reward_coef': 0.044391238078361046, 'sentiment_reward_coef': 0.01553354729142637, 'episode_length': 486}
# Best value (final net worth): 48291.781432057585
# Episode 1 | Total Reward: 1.87 | Net Worth: 29191.20 | Action Mean: -0.19, Std: 0.64
# Episode 2 | Total Reward: 0.96 | Net Worth: 31893.60 | Action Mean: -0.03, Std: 0.70
# Episode 3 | Total Reward: 2.19 | Net Worth: 37036.81 | Action Mean: -0.15, Std: 0.65
# Episode 4 | Total Reward: 2.18 | Net Worth: 36471.65 | Action Mean: -0.15, Std: 0.67
# Episode 5 | Total Reward: 0.90 | Net Worth: 25425.00 | Action Mean: -0.09, Std: 0.65
# Episode 6 | Total Reward: 2.55 | Net Worth: 30440.43 | Action Mean: -0.07, Std: 0.67
# Episode 7 | Total Reward: 1.46 | Net Worth: 21544.48 | Action Mean: -0.16, Std: 0.65
# Episode 8 | Total Reward: 1.72 | Net Worth: 24882.03 | Action Mean: -0.12, Std: 0.66
# Episode 9 | Total Reward: 0.98 | Net Worth: 30062.00 | Action Mean: -0.24, Std: 0.65
# Episode 10 | Total Reward: 2.44 | Net Worth: 29763.24 | Action Mean: -0.18, Std: 0.63 | Sharpe Ratio: 4.258
# Episode 11 | Total Reward: 0.58 | Net Worth: 20414.70 | Action Mean: -0.13, Std: 0.65
# Episode 12 | Total Reward: 1.25 | Net Worth: 25914.60 | Action Mean: -0.14, Std: 0.67
# Episode 13 | Total Reward: 2.03 | Net Worth: 32384.15 | Action Mean: -0.08, Std: 0.63
# Episode 14 | Total Reward: 1.73 | Net Worth: 27102.54 | Action Mean: -0.05, Std: 0.67
# Episode 15 | Total Reward: 2.50 | Net Worth: 37138.71 | Action Mean: -0.17, Std: 0.63
# Episode 16 | Total Reward: 2.56 | Net Worth: 33922.84 | Action Mean: -0.08, Std: 0.63
# Episode 17 | Total Reward: 2.09 | Net Worth: 30822.91 | Action Mean: -0.14, Std: 0.69
# Episode 18 | Total Reward: 0.26 | Net Worth: 23684.30 | Action Mean: -0.25, Std: 0.59
# Episode 19 | Total Reward: 1.24 | Net Worth: 29293.73 | Action Mean: -0.21, Std: 0.62
# Episode 20 | Total Reward: 1.43 | Net Worth: 31493.01 | Action Mean: -0.09, Std: 0.61 | Sharpe Ratio: 4.143
# Episode 21 | Total Reward: 2.62 | Net Worth: 35548.99 | Action Mean: -0.18, Std: 0.61
# Episode 22 | Total Reward: 2.95 | Net Worth: 40033.95 | Action Mean: -0.11, Std: 0.67
# Episode 23 | Total Reward: 0.60 | Net Worth: 23146.53 | Action Mean: 0.00, Std: 0.64
# Episode 24 | Total Reward: 0.66 | Net Worth: 28296.38 | Action Mean: -0.25, Std: 0.58
# Episode 25 | Total Reward: -0.14 | Net Worth: 23639.34 | Action Mean: -0.09, Std: 0.61
# Episode 26 | Total Reward: 3.79 | Net Worth: 44617.45 | Action Mean: -0.14, Std: 0.63
# Episode 27 | Total Reward: 0.04 | Net Worth: 25760.08 | Action Mean: -0.19, Std: 0.58
# Episode 28 | Total Reward: 2.11 | Net Worth: 29854.33 | Action Mean: -0.04, Std: 0.61
# Episode 29 | Total Reward: 1.11 | Net Worth: 25965.19 | Action Mean: -0.13, Std: 0.62
# Episode 30 | Total Reward: 0.85 | Net Worth: 19475.76 | Action Mean: -0.19, Std: 0.59 | Sharpe Ratio: 3.345
# Episode 31 | Total Reward: 2.80 | Net Worth: 34784.93 | Action Mean: -0.18, Std: 0.60
# Episode 32 | Total Reward: 0.44 | Net Worth: 35171.51 | Action Mean: -0.17, Std: 0.63
# Episode 33 | Total Reward: 1.52 | Net Worth: 26395.70 | Action Mean: -0.18, Std: 0.57
# Episode 34 | Total Reward: 1.25 | Net Worth: 27858.94 | Action Mean: -0.15, Std: 0.61
# Episode 35 | Total Reward: 2.66 | Net Worth: 41866.50 | Action Mean: -0.19, Std: 0.60
# Episode 36 | Total Reward: 2.25 | Net Worth: 27188.09 | Action Mean: -0.20, Std: 0.60
# Episode 37 | Total Reward: 1.26 | Net Worth: 23220.87 | Action Mean: -0.05, Std: 0.66
# Episode 38 | Total Reward: 1.54 | Net Worth: 29234.26 | Action Mean: -0.18, Std: 0.56
# Episode 39 | Total Reward: 1.52 | Net Worth: 28675.06 | Action Mean: -0.15, Std: 0.57
# Episode 40 | Total Reward: 2.50 | Net Worth: 33997.37 | Action Mean: -0.07, Std: 0.61 | Sharpe Ratio: 3.472
# Episode 41 | Total Reward: 1.67 | Net Worth: 31945.20 | Action Mean: -0.08, Std: 0.60
# Episode 42 | Total Reward: 2.37 | Net Worth: 31405.81 | Action Mean: -0.10, Std: 0.60
# Episode 43 | Total Reward: 1.29 | Net Worth: 24556.82 | Action Mean: -0.16, Std: 0.59
# Episode 44 | Total Reward: 2.70 | Net Worth: 30174.07 | Action Mean: -0.14, Std: 0.58
# Episode 45 | Total Reward: 1.13 | Net Worth: 24929.20 | Action Mean: -0.11, Std: 0.62
# Episode 46 | Total Reward: 1.53 | Net Worth: 38155.43 | Action Mean: -0.23, Std: 0.55
# Episode 47 | Total Reward: 1.47 | Net Worth: 35845.88 | Action Mean: -0.12, Std: 0.59
# Episode 48 | Total Reward: 0.05 | Net Worth: 26672.73 | Action Mean: -0.11, Std: 0.59
# Episode 49 | Total Reward: 2.23 | Net Worth: 39386.00 | Action Mean: -0.13, Std: 0.60
# Episode 50 | Total Reward: 0.97 | Net Worth: 32973.64 | Action Mean: -0.21, Std: 0.57 | Sharpe Ratio: 3.597
# Episode 51 | Total Reward: 2.30 | Net Worth: 32632.43 | Action Mean: -0.13, Std: 0.61
# Episode 52 | Total Reward: 0.95 | Net Worth: 24950.35 | Action Mean: -0.14, Std: 0.59
# Episode 53 | Total Reward: 3.19 | Net Worth: 34493.99 | Action Mean: -0.20, Std: 0.57
# Episode 54 | Total Reward: 2.07 | Net Worth: 36292.68 | Action Mean: -0.17, Std: 0.60
# Episode 55 | Total Reward: 1.68 | Net Worth: 31830.43 | Action Mean: -0.14, Std: 0.60
# Episode 56 | Total Reward: 2.21 | Net Worth: 35063.28 | Action Mean: -0.13, Std: 0.57
# Episode 57 | Total Reward: 1.19 | Net Worth: 22816.31 | Action Mean: -0.18, Std: 0.58
# Episode 58 | Total Reward: 2.05 | Net Worth: 34508.66 | Action Mean: -0.20, Std: 0.57
# Episode 59 | Total Reward: 1.07 | Net Worth: 25965.37 | Action Mean: -0.24, Std: 0.55
# Episode 60 | Total Reward: 0.33 | Net Worth: 24712.81 | Action Mean: -0.18, Std: 0.60 | Sharpe Ratio: 3.679
# Episode 61 | Total Reward: 0.18 | Net Worth: 21056.16 | Action Mean: -0.13, Std: 0.60
# Episode 62 | Total Reward: 0.26 | Net Worth: 20439.63 | Action Mean: -0.14, Std: 0.53
# Episode 63 | Total Reward: 2.06 | Net Worth: 30515.65 | Action Mean: -0.15, Std: 0.55
# Episode 64 | Total Reward: 1.27 | Net Worth: 22588.42 | Action Mean: -0.07, Std: 0.55
# Episode 65 | Total Reward: 0.65 | Net Worth: 25404.81 | Action Mean: -0.16, Std: 0.55
# Episode 66 | Total Reward: 1.34 | Net Worth: 30322.73 | Action Mean: -0.13, Std: 0.54
# Episode 67 | Total Reward: 1.16 | Net Worth: 28058.93 | Action Mean: -0.09, Std: 0.52
# Episode 68 | Total Reward: 2.06 | Net Worth: 33832.66 | Action Mean: -0.20, Std: 0.57
# Episode 69 | Total Reward: 1.87 | Net Worth: 34302.37 | Action Mean: -0.12, Std: 0.55
# Episode 70 | Total Reward: 0.97 | Net Worth: 26557.89 | Action Mean: -0.15, Std: 0.60 | Sharpe Ratio: 3.608
# Episode 71 | Total Reward: 1.06 | Net Worth: 22690.84 | Action Mean: -0.19, Std: 0.53
# Episode 72 | Total Reward: 2.62 | Net Worth: 38662.61 | Action Mean: -0.19, Std: 0.53
# Episode 73 | Total Reward: 1.47 | Net Worth: 22277.92 | Action Mean: -0.15, Std: 0.59
# Episode 74 | Total Reward: 1.32 | Net Worth: 33789.63 | Action Mean: -0.17, Std: 0.54
# Episode 75 | Total Reward: 1.91 | Net Worth: 35388.51 | Action Mean: -0.11, Std: 0.52
# Episode 76 | Total Reward: 1.30 | Net Worth: 36953.12 | Action Mean: -0.19, Std: 0.52
# Episode 77 | Total Reward: 0.89 | Net Worth: 29863.76 | Action Mean: -0.10, Std: 0.53
# Episode 78 | Total Reward: 1.25 | Net Worth: 24823.88 | Action Mean: -0.14, Std: 0.53
# Episode 79 | Total Reward: 1.69 | Net Worth: 32700.32 | Action Mean: -0.24, Std: 0.51
# Episode 80 | Total Reward: 0.30 | Net Worth: 22661.48 | Action Mean: -0.18, Std: 0.53 | Sharpe Ratio: 3.563
# Episode 81 | Total Reward: 0.48 | Net Worth: 19330.17 | Action Mean: -0.20, Std: 0.48
# Episode 82 | Total Reward: 1.18 | Net Worth: 27360.35 | Action Mean: -0.19, Std: 0.53
# Episode 83 | Total Reward: 0.74 | Net Worth: 22950.93 | Action Mean: -0.18, Std: 0.55
# Episode 84 | Total Reward: 1.94 | Net Worth: 31463.83 | Action Mean: -0.17, Std: 0.53
# Episode 85 | Total Reward: 2.07 | Net Worth: 36217.64 | Action Mean: -0.20, Std: 0.53
# Episode 86 | Total Reward: 2.34 | Net Worth: 37799.86 | Action Mean: -0.16, Std: 0.55
# Episode 87 | Total Reward: 1.23 | Net Worth: 31522.96 | Action Mean: -0.20, Std: 0.50
# Episode 88 | Total Reward: 1.18 | Net Worth: 30992.49 | Action Mean: -0.18, Std: 0.54
# Episode 89 | Total Reward: 0.40 | Net Worth: 24409.35 | Action Mean: -0.18, Std: 0.53
# Episode 90 | Total Reward: 1.76 | Net Worth: 29409.43 | Action Mean: -0.16, Std: 0.49 | Sharpe Ratio: 3.553
# Episode 91 | Total Reward: 1.42 | Net Worth: 32515.23 | Action Mean: -0.19, Std: 0.50
# Episode 92 | Total Reward: 2.12 | Net Worth: 32742.53 | Action Mean: -0.22, Std: 0.51
# Episode 93 | Total Reward: 2.25 | Net Worth: 36432.26 | Action Mean: -0.17, Std: 0.46
# Episode 94 | Total Reward: 1.75 | Net Worth: 31838.12 | Action Mean: -0.12, Std: 0.52
# Episode 95 | Total Reward: 1.94 | Net Worth: 35965.63 | Action Mean: -0.20, Std: 0.50
# Episode 96 | Total Reward: -0.22 | Net Worth: 21090.75 | Action Mean: -0.16, Std: 0.48
# Episode 97 | Total Reward: 2.91 | Net Worth: 35569.15 | Action Mean: -0.13, Std: 0.51
# Episode 98 | Total Reward: 0.45 | Net Worth: 23652.23 | Action Mean: -0.17, Std: 0.51
# Episode 99 | Total Reward: 1.69 | Net Worth: 24517.54 | Action Mean: -0.19, Std: 0.52
# Episode 100 | Total Reward: 2.46 | Net Worth: 36637.29 | Action Mean: -0.16, Std: 0.51 | Sharpe Ratio: 3.569
# Episode 101 | Total Reward: 2.01 | Net Worth: 29213.76 | Action Mean: -0.24, Std: 0.48
# Episode 102 | Total Reward: 2.56 | Net Worth: 34946.00 | Action Mean: -0.14, Std: 0.46
# Episode 103 | Total Reward: -0.07 | Net Worth: 20922.17 | Action Mean: -0.13, Std: 0.47
# Episode 104 | Total Reward: 1.13 | Net Worth: 23820.66 | Action Mean: -0.15, Std: 0.49
# Episode 105 | Total Reward: 2.93 | Net Worth: 37665.75 | Action Mean: -0.14, Std: 0.45
# Episode 106 | Total Reward: 0.57 | Net Worth: 23617.17 | Action Mean: -0.14, Std: 0.50
# Episode 107 | Total Reward: 0.91 | Net Worth: 18470.13 | Action Mean: -0.18, Std: 0.47
# Episode 108 | Total Reward: 0.60 | Net Worth: 23228.51 | Action Mean: -0.20, Std: 0.44
# Episode 109 | Total Reward: 2.16 | Net Worth: 35065.71 | Action Mean: -0.16, Std: 0.44
# Episode 110 | Total Reward: 1.30 | Net Worth: 25685.75 | Action Mean: -0.21, Std: 0.44 | Sharpe Ratio: 3.396
# Episode 111 | Total Reward: 0.58 | Net Worth: 20790.96 | Action Mean: -0.24, Std: 0.47
# Episode 112 | Total Reward: 0.61 | Net Worth: 18940.54 | Action Mean: -0.18, Std: 0.46
# Episode 113 | Total Reward: 1.07 | Net Worth: 23576.45 | Action Mean: -0.21, Std: 0.48
# Episode 114 | Total Reward: 1.17 | Net Worth: 29904.46 | Action Mean: -0.15, Std: 0.50
# Episode 115 | Total Reward: 1.98 | Net Worth: 32154.36 | Action Mean: -0.17, Std: 0.46
# Episode 116 | Total Reward: 1.36 | Net Worth: 23951.04 | Action Mean: -0.18, Std: 0.43
# Episode 117 | Total Reward: 0.76 | Net Worth: 22285.65 | Action Mean: -0.28, Std: 0.43
# Episode 118 | Total Reward: 0.65 | Net Worth: 28877.81 | Action Mean: -0.23, Std: 0.47
# Episode 119 | Total Reward: 0.24 | Net Worth: 22667.35 | Action Mean: -0.13, Std: 0.54
# Episode 120 | Total Reward: 1.73 | Net Worth: 30115.49 | Action Mean: -0.23, Std: 0.42 | Sharpe Ratio: 3.266
# Episode 121 | Total Reward: 1.73 | Net Worth: 36930.49 | Action Mean: -0.14, Std: 0.51
# Episode 122 | Total Reward: 2.24 | Net Worth: 38351.37 | Action Mean: -0.22, Std: 0.43
# Episode 123 | Total Reward: 0.01 | Net Worth: 21463.61 | Action Mean: -0.10, Std: 0.48
# Episode 124 | Total Reward: 1.81 | Net Worth: 33553.24 | Action Mean: -0.24, Std: 0.47
# Episode 125 | Total Reward: 1.39 | Net Worth: 26096.45 | Action Mean: -0.19, Std: 0.43
# Episode 126 | Total Reward: 1.23 | Net Worth: 28452.74 | Action Mean: -0.17, Std: 0.43
# Episode 127 | Total Reward: 1.24 | Net Worth: 23343.75 | Action Mean: -0.19, Std: 0.40
# Episode 128 | Total Reward: 1.34 | Net Worth: 32240.55 | Action Mean: -0.23, Std: 0.45
# Episode 129 | Total Reward: 1.70 | Net Worth: 33210.06 | Action Mean: -0.20, Std: 0.46
# Episode 130 | Total Reward: 1.35 | Net Worth: 34564.91 | Action Mean: -0.23, Std: 0.47 | Sharpe Ratio: 3.418
# Episode 131 | Total Reward: 1.35 | Net Worth: 30006.76 | Action Mean: -0.23, Std: 0.43
# Episode 132 | Total Reward: 1.18 | Net Worth: 23593.35 | Action Mean: -0.20, Std: 0.46
# Episode 133 | Total Reward: 0.53 | Net Worth: 23890.45 | Action Mean: -0.21, Std: 0.43
# Episode 134 | Total Reward: 1.43 | Net Worth: 27360.63 | Action Mean: -0.27, Std: 0.40
# Episode 135 | Total Reward: 0.92 | Net Worth: 24722.79 | Action Mean: -0.20, Std: 0.44
# Episode 136 | Total Reward: 1.26 | Net Worth: 33839.55 | Action Mean: -0.14, Std: 0.49
# Episode 137 | Total Reward: 1.20 | Net Worth: 28836.31 | Action Mean: -0.14, Std: 0.43
# Episode 138 | Total Reward: 0.87 | Net Worth: 29327.71 | Action Mean: -0.24, Std: 0.42
# Episode 139 | Total Reward: 0.66 | Net Worth: 25309.30 | Action Mean: -0.16, Std: 0.44
# Episode 140 | Total Reward: 0.38 | Net Worth: 19939.35 | Action Mean: -0.15, Std: 0.45 | Sharpe Ratio: 3.396
# Episode 141 | Total Reward: 0.77 | Net Worth: 28745.40 | Action Mean: -0.10, Std: 0.36
# Episode 142 | Total Reward: 0.76 | Net Worth: 28997.98 | Action Mean: -0.19, Std: 0.44
# Episode 143 | Total Reward: 1.74 | Net Worth: 27766.70 | Action Mean: -0.15, Std: 0.41
# Episode 144 | Total Reward: 1.55 | Net Worth: 33000.73 | Action Mean: -0.20, Std: 0.44
# Episode 145 | Total Reward: 1.23 | Net Worth: 33220.06 | Action Mean: -0.19, Std: 0.43
# Episode 146 | Total Reward: 0.95 | Net Worth: 32269.95 | Action Mean: -0.13, Std: 0.39
# Episode 147 | Total Reward: 1.04 | Net Worth: 25844.47 | Action Mean: -0.20, Std: 0.41
# Episode 148 | Total Reward: 0.27 | Net Worth: 24127.23 | Action Mean: -0.18, Std: 0.40
# Episode 149 | Total Reward: 0.34 | Net Worth: 21190.86 | Action Mean: -0.21, Std: 0.41
# Episode 150 | Total Reward: 0.83 | Net Worth: 27082.07 | Action Mean: -0.22, Std: 0.40 | Sharpe Ratio: 3.437
# Episode 151 | Total Reward: 0.84 | Net Worth: 20713.16 | Action Mean: -0.20, Std: 0.37
# Episode 152 | Total Reward: 0.80 | Net Worth: 22576.27 | Action Mean: -0.15, Std: 0.38
# Episode 153 | Total Reward: 0.97 | Net Worth: 23376.68 | Action Mean: -0.17, Std: 0.43
# Episode 154 | Total Reward: 1.54 | Net Worth: 29718.94 | Action Mean: -0.25, Std: 0.37
# Episode 155 | Total Reward: 2.16 | Net Worth: 32702.74 | Action Mean: -0.20, Std: 0.41
# Episode 156 | Total Reward: 0.64 | Net Worth: 19305.33 | Action Mean: -0.16, Std: 0.39
# Episode 157 | Total Reward: 0.71 | Net Worth: 19384.53 | Action Mean: -0.19, Std: 0.42
# Episode 158 | Total Reward: 1.39 | Net Worth: 30429.16 | Action Mean: -0.23, Std: 0.38
# Episode 159 | Total Reward: -0.31 | Net Worth: 21465.91 | Action Mean: -0.15, Std: 0.40
# Episode 160 | Total Reward: -0.06 | Net Worth: 19366.11 | Action Mean: -0.19, Std: 0.36 | Sharpe Ratio: 3.237
# Episode 161 | Total Reward: 1.78 | Net Worth: 27044.74 | Action Mean: -0.17, Std: 0.38
# Episode 162 | Total Reward: 0.03 | Net Worth: 25018.47 | Action Mean: -0.16, Std: 0.40
# Episode 163 | Total Reward: 2.11 | Net Worth: 32161.88 | Action Mean: -0.20, Std: 0.37
# Episode 164 | Total Reward: 1.22 | Net Worth: 25077.43 | Action Mean: -0.16, Std: 0.38
# Episode 165 | Total Reward: 1.52 | Net Worth: 28958.83 | Action Mean: -0.20, Std: 0.42
# Episode 166 | Total Reward: 1.66 | Net Worth: 29339.74 | Action Mean: -0.16, Std: 0.38
# Episode 167 | Total Reward: 0.35 | Net Worth: 18910.70 | Action Mean: -0.20, Std: 0.39
# Episode 168 | Total Reward: 1.84 | Net Worth: 29472.74 | Action Mean: -0.20, Std: 0.42
# Episode 169 | Total Reward: 1.99 | Net Worth: 36915.31 | Action Mean: -0.18, Std: 0.38
# Episode 170 | Total Reward: 1.35 | Net Worth: 28727.99 | Action Mean: -0.14, Std: 0.35 | Sharpe Ratio: 3.267
# Episode 171 | Total Reward: 0.68 | Net Worth: 21629.03 | Action Mean: -0.27, Std: 0.36
# Episode 172 | Total Reward: 0.98 | Net Worth: 28197.35 | Action Mean: -0.23, Std: 0.37
# Episode 173 | Total Reward: -0.33 | Net Worth: 18172.03 | Action Mean: -0.22, Std: 0.38
# Episode 174 | Total Reward: 0.50 | Net Worth: 22284.02 | Action Mean: -0.16, Std: 0.35
# Episode 175 | Total Reward: 1.36 | Net Worth: 31958.42 | Action Mean: -0.27, Std: 0.34
# Episode 176 | Total Reward: 1.17 | Net Worth: 25272.95 | Action Mean: -0.21, Std: 0.29
# Episode 177 | Total Reward: 0.81 | Net Worth: 25084.36 | Action Mean: -0.24, Std: 0.38
# Episode 178 | Total Reward: 0.30 | Net Worth: 19350.91 | Action Mean: -0.13, Std: 0.33
# Episode 179 | Total Reward: 1.54 | Net Worth: 32905.15 | Action Mean: -0.16, Std: 0.38
# Episode 180 | Total Reward: 1.20 | Net Worth: 24708.51 | Action Mean: -0.22, Std: 0.38 | Sharpe Ratio: 3.237
# Episode 181 | Total Reward: 0.45 | Net Worth: 19217.66 | Action Mean: -0.20, Std: 0.34
# Episode 182 | Total Reward: 1.08 | Net Worth: 27171.15 | Action Mean: -0.16, Std: 0.41
# Episode 183 | Total Reward: 0.83 | Net Worth: 25067.42 | Action Mean: -0.26, Std: 0.36
# Episode 184 | Total Reward: 0.69 | Net Worth: 19239.02 | Action Mean: -0.24, Std: 0.36
# Episode 185 | Total Reward: 0.67 | Net Worth: 19011.66 | Action Mean: -0.22, Std: 0.39
# Episode 186 | Total Reward: 0.24 | Net Worth: 20183.34 | Action Mean: -0.17, Std: 0.36
# Episode 187 | Total Reward: 1.01 | Net Worth: 29669.94 | Action Mean: -0.22, Std: 0.34
# Episode 188 | Total Reward: 2.23 | Net Worth: 34815.60 | Action Mean: -0.23, Std: 0.33
# Episode 189 | Total Reward: 0.21 | Net Worth: 21896.93 | Action Mean: -0.20, Std: 0.30
# Episode 190 | Total Reward: 0.37 | Net Worth: 21418.15 | Action Mean: -0.22, Std: 0.32 | Sharpe Ratio: 3.114
# Episode 191 | Total Reward: -0.06 | Net Worth: 19061.07 | Action Mean: -0.21, Std: 0.38
# Episode 192 | Total Reward: 1.14 | Net Worth: 28046.36 | Action Mean: -0.19, Std: 0.36
# Episode 193 | Total Reward: 0.48 | Net Worth: 20163.61 | Action Mean: -0.22, Std: 0.34
# Episode 194 | Total Reward: 0.72 | Net Worth: 26961.40 | Action Mean: -0.19, Std: 0.34
# Episode 195 | Total Reward: 0.06 | Net Worth: 21912.71 | Action Mean: -0.18, Std: 0.34
# Episode 196 | Total Reward: 1.00 | Net Worth: 22728.24 | Action Mean: -0.20, Std: 0.35
# Episode 197 | Total Reward: 0.99 | Net Worth: 24750.06 | Action Mean: -0.21, Std: 0.36
# Episode 198 | Total Reward: 1.90 | Net Worth: 31742.64 | Action Mean: -0.18, Std: 0.33
# Episode 199 | Total Reward: 0.18 | Net Worth: 20396.20 | Action Mean: -0.21, Std: 0.29
# Episode 200 | Total Reward: 0.49 | Net Worth: 21316.98 | Action Mean: -0.23, Std: 0.33 | Sharpe Ratio: 3.122
# Episode 201 | Total Reward: 1.36 | Net Worth: 32193.25 | Action Mean: -0.20, Std: 0.35
# Episode 202 | Total Reward: 0.96 | Net Worth: 24546.20 | Action Mean: -0.21, Std: 0.32
# Episode 203 | Total Reward: 0.62 | Net Worth: 22136.26 | Action Mean: -0.20, Std: 0.36
# Episode 204 | Total Reward: 1.48 | Net Worth: 25571.38 | Action Mean: -0.22, Std: 0.33
# Episode 205 | Total Reward: 0.73 | Net Worth: 24384.20 | Action Mean: -0.20, Std: 0.37
# Episode 206 | Total Reward: 1.10 | Net Worth: 24493.33 | Action Mean: -0.15, Std: 0.33
# Episode 207 | Total Reward: 0.40 | Net Worth: 19715.44 | Action Mean: -0.19, Std: 0.36
# Episode 208 | Total Reward: 0.44 | Net Worth: 18528.20 | Action Mean: -0.23, Std: 0.30
# Episode 209 | Total Reward: -0.24 | Net Worth: 19700.57 | Action Mean: -0.18, Std: 0.32
# Episode 210 | Total Reward: 1.93 | Net Worth: 29886.79 | Action Mean: -0.14, Std: 0.34 | Sharpe Ratio: 3.175
# Episode 211 | Total Reward: 0.66 | Net Worth: 27507.55 | Action Mean: -0.25, Std: 0.30
# Episode 212 | Total Reward: 0.02 | Net Worth: 19718.28 | Action Mean: -0.22, Std: 0.33
# Episode 213 | Total Reward: 1.28 | Net Worth: 27148.34 | Action Mean: -0.23, Std: 0.28
# Episode 214 | Total Reward: 1.19 | Net Worth: 29067.87 | Action Mean: -0.14, Std: 0.34
# Episode 215 | Total Reward: 1.23 | Net Worth: 31251.84 | Action Mean: -0.21, Std: 0.35
# Episode 216 | Total Reward: 0.51 | Net Worth: 19591.90 | Action Mean: -0.24, Std: 0.35
# Episode 217 | Total Reward: 0.37 | Net Worth: 23918.12 | Action Mean: -0.21, Std: 0.30
# Episode 218 | Total Reward: 0.72 | Net Worth: 21730.43 | Action Mean: -0.18, Std: 0.33
# Episode 219 | Total Reward: 0.48 | Net Worth: 24973.45 | Action Mean: -0.25, Std: 0.29
# Episode 220 | Total Reward: 0.55 | Net Worth: 21563.66 | Action Mean: -0.22, Std: 0.31 | Sharpe Ratio: 3.179
# Episode 221 | Total Reward: 0.70 | Net Worth: 29042.87 | Action Mean: -0.20, Std: 0.33
# Episode 222 | Total Reward: 0.94 | Net Worth: 30864.67 | Action Mean: -0.22, Std: 0.30
# Episode 223 | Total Reward: 0.91 | Net Worth: 21597.85 | Action Mean: -0.20, Std: 0.34
# Episode 224 | Total Reward: 1.17 | Net Worth: 27884.47 | Action Mean: -0.19, Std: 0.33
# Episode 225 | Total Reward: 1.67 | Net Worth: 33084.78 | Action Mean: -0.22, Std: 0.30
# Episode 226 | Total Reward: -0.25 | Net Worth: 19507.88 | Action Mean: -0.22, Std: 0.34
# Episode 227 | Total Reward: 0.01 | Net Worth: 18126.86 | Action Mean: -0.19, Std: 0.31
# Episode 228 | Total Reward: -0.13 | Net Worth: 17251.86 | Action Mean: -0.20, Std: 0.28
# Episode 229 | Total Reward: 1.05 | Net Worth: 28340.40 | Action Mean: -0.22, Std: 0.30
# Episode 230 | Total Reward: 0.45 | Net Worth: 21846.97 | Action Mean: -0.13, Std: 0.29 | Sharpe Ratio: 3.235
# Episode 231 | Total Reward: 1.94 | Net Worth: 33823.45 | Action Mean: -0.22, Std: 0.30
# Episode 232 | Total Reward: -0.03 | Net Worth: 20153.80 | Action Mean: -0.25, Std: 0.32
# Episode 233 | Total Reward: 0.26 | Net Worth: 20051.96 | Action Mean: -0.16, Std: 0.29
# Episode 234 | Total Reward: 0.35 | Net Worth: 24257.92 | Action Mean: -0.23, Std: 0.32
# Episode 235 | Total Reward: 1.11 | Net Worth: 23770.45 | Action Mean: -0.23, Std: 0.32
# Episode 236 | Total Reward: 0.25 | Net Worth: 23177.06 | Action Mean: -0.24, Std: 0.29
# Episode 237 | Total Reward: 1.14 | Net Worth: 26555.73 | Action Mean: -0.24, Std: 0.28
# Episode 238 | Total Reward: 1.21 | Net Worth: 30130.32 | Action Mean: -0.18, Std: 0.31
# Episode 239 | Total Reward: -0.15 | Net Worth: 18140.29 | Action Mean: -0.20, Std: 0.28
# Episode 240 | Total Reward: -0.27 | Net Worth: 19256.75 | Action Mean: -0.19, Std: 0.33 | Sharpe Ratio: 3.123
# Episode 241 | Total Reward: 0.36 | Net Worth: 19029.68 | Action Mean: -0.20, Std: 0.29
# Episode 242 | Total Reward: 0.94 | Net Worth: 28021.76 | Action Mean: -0.24, Std: 0.29
# Episode 243 | Total Reward: 0.96 | Net Worth: 22204.49 | Action Mean: -0.24, Std: 0.29
# Episode 244 | Total Reward: 1.01 | Net Worth: 25129.71 | Action Mean: -0.24, Std: 0.28
# Episode 245 | Total Reward: 0.73 | Net Worth: 26952.91 | Action Mean: -0.19, Std: 0.29
# Episode 246 | Total Reward: 0.00 | Net Worth: 21896.13 | Action Mean: -0.21, Std: 0.28
# Episode 247 | Total Reward: 1.28 | Net Worth: 29185.74 | Action Mean: -0.17, Std: 0.31
# Episode 248 | Total Reward: 0.35 | Net Worth: 18633.96 | Action Mean: -0.25, Std: 0.28
# Episode 249 | Total Reward: 1.58 | Net Worth: 30958.48 | Action Mean: -0.20, Std: 0.31
# Episode 250 | Total Reward: 0.84 | Net Worth: 26078.97 | Action Mean: -0.20, Std: 0.29 | Sharpe Ratio: 3.114
# Episode 251 | Total Reward: 0.64 | Net Worth: 18822.26 | Action Mean: -0.26, Std: 0.27
# Episode 252 | Total Reward: 1.91 | Net Worth: 32798.93 | Action Mean: -0.20, Std: 0.30
# Episode 253 | Total Reward: 0.78 | Net Worth: 26882.59 | Action Mean: -0.23, Std: 0.28
# Episode 254 | Total Reward: 2.12 | Net Worth: 33521.33 | Action Mean: -0.19, Std: 0.31
# Episode 255 | Total Reward: -0.00 | Net Worth: 20210.34 | Action Mean: -0.18, Std: 0.25
# Episode 256 | Total Reward: 0.40 | Net Worth: 21205.08 | Action Mean: -0.23, Std: 0.30
# Episode 257 | Total Reward: 0.88 | Net Worth: 27084.19 | Action Mean: -0.20, Std: 0.30
# Episode 258 | Total Reward: 0.73 | Net Worth: 21521.03 | Action Mean: -0.24, Std: 0.28
# Episode 259 | Total Reward: 1.32 | Net Worth: 30888.30 | Action Mean: -0.17, Std: 0.29
# Episode 260 | Total Reward: 0.64 | Net Worth: 24191.91 | Action Mean: -0.21, Std: 0.26 | Sharpe Ratio: 3.134
# Episode 261 | Total Reward: 1.80 | Net Worth: 33873.16 | Action Mean: -0.22, Std: 0.28
# Episode 262 | Total Reward: 0.92 | Net Worth: 28836.64 | Action Mean: -0.22, Std: 0.28
# Episode 263 | Total Reward: -0.12 | Net Worth: 19588.79 | Action Mean: -0.22, Std: 0.30
# Episode 264 | Total Reward: 0.48 | Net Worth: 23101.10 | Action Mean: -0.25, Std: 0.31
# Episode 265 | Total Reward: 1.19 | Net Worth: 25131.92 | Action Mean: -0.22, Std: 0.25
# Episode 266 | Total Reward: 0.04 | Net Worth: 17821.00 | Action Mean: -0.20, Std: 0.26
# Episode 267 | Total Reward: 0.11 | Net Worth: 21784.81 | Action Mean: -0.21, Std: 0.26
# Episode 268 | Total Reward: 0.52 | Net Worth: 24209.94 | Action Mean: -0.26, Std: 0.26
# Episode 269 | Total Reward: 0.62 | Net Worth: 28377.03 | Action Mean: -0.22, Std: 0.27
# Episode 270 | Total Reward: -0.03 | Net Worth: 19130.63 | Action Mean: -0.19, Std: 0.25 | Sharpe Ratio: 3.117
# Episode 271 | Total Reward: 0.93 | Net Worth: 23587.40 | Action Mean: -0.23, Std: 0.27
# Episode 272 | Total Reward: -0.19 | Net Worth: 17320.32 | Action Mean: -0.20, Std: 0.25
# Episode 273 | Total Reward: 0.74 | Net Worth: 22146.32 | Action Mean: -0.24, Std: 0.25
# Episode 274 | Total Reward: 1.17 | Net Worth: 30179.16 | Action Mean: -0.21, Std: 0.26
# Episode 275 | Total Reward: -0.00 | Net Worth: 19880.92 | Action Mean: -0.25, Std: 0.25
# Episode 276 | Total Reward: 0.44 | Net Worth: 21731.61 | Action Mean: -0.24, Std: 0.27
# Episode 277 | Total Reward: 0.64 | Net Worth: 22771.32 | Action Mean: -0.19, Std: 0.25
# Episode 278 | Total Reward: 0.56 | Net Worth: 23983.93 | Action Mean: -0.25, Std: 0.27
# Episode 279 | Total Reward: 1.60 | Net Worth: 30666.65 | Action Mean: -0.23, Std: 0.26
# Episode 280 | Total Reward: 0.10 | Net Worth: 19175.01 | Action Mean: -0.21, Std: 0.29 | Sharpe Ratio: 3.105
# Episode 281 | Total Reward: 0.42 | Net Worth: 21164.64 | Action Mean: -0.25, Std: 0.27
# Episode 282 | Total Reward: 0.20 | Net Worth: 19767.35 | Action Mean: -0.25, Std: 0.23
# Episode 283 | Total Reward: 0.52 | Net Worth: 21572.91 | Action Mean: -0.20, Std: 0.25
# Episode 284 | Total Reward: 1.34 | Net Worth: 32013.25 | Action Mean: -0.24, Std: 0.26
# Episode 285 | Total Reward: -0.10 | Net Worth: 17204.83 | Action Mean: -0.22, Std: 0.26
# Episode 286 | Total Reward: -0.34 | Net Worth: 18129.59 | Action Mean: -0.23, Std: 0.28
# Episode 287 | Total Reward: 0.08 | Net Worth: 20535.47 | Action Mean: -0.19, Std: 0.26
# Episode 288 | Total Reward: 0.81 | Net Worth: 26394.37 | Action Mean: -0.21, Std: 0.24
# Episode 289 | Total Reward: 0.31 | Net Worth: 22862.79 | Action Mean: -0.21, Std: 0.30
# Episode 290 | Total Reward: 0.49 | Net Worth: 21136.38 | Action Mean: -0.21, Std: 0.27 | Sharpe Ratio: 3.102
# Episode 291 | Total Reward: 1.66 | Net Worth: 32162.39 | Action Mean: -0.22, Std: 0.29
# Episode 292 | Total Reward: 0.17 | Net Worth: 17648.57 | Action Mean: -0.18, Std: 0.28
# Episode 293 | Total Reward: 0.61 | Net Worth: 25796.52 | Action Mean: -0.20, Std: 0.25
# Episode 294 | Total Reward: 0.66 | Net Worth: 21662.13 | Action Mean: -0.24, Std: 0.25
# Episode 295 | Total Reward: 0.70 | Net Worth: 27881.36 | Action Mean: -0.23, Std: 0.24
# Episode 296 | Total Reward: 0.19 | Net Worth: 17069.98 | Action Mean: -0.22, Std: 0.27
# Episode 297 | Total Reward: 0.18 | Net Worth: 17980.81 | Action Mean: -0.18, Std: 0.26
# Episode 298 | Total Reward: 0.61 | Net Worth: 25692.15 | Action Mean: -0.18, Std: 0.27
# Episode 299 | Total Reward: 0.41 | Net Worth: 21081.64 | Action Mean: -0.25, Std: 0.27
# Episode 300 | Total Reward: 0.19 | Net Worth: 18195.90 | Action Mean: -0.25, Std: 0.28 | Sharpe Ratio: 2.997
# Episode 301 | Total Reward: 1.70 | Net Worth: 33063.60 | Action Mean: -0.20, Std: 0.25
# Episode 302 | Total Reward: 0.05 | Net Worth: 19802.81 | Action Mean: -0.22, Std: 0.23
# Episode 303 | Total Reward: 0.29 | Net Worth: 20328.72 | Action Mean: -0.21, Std: 0.25
# Episode 304 | Total Reward: -0.08 | Net Worth: 16909.31 | Action Mean: -0.20, Std: 0.21
# Episode 305 | Total Reward: 0.73 | Net Worth: 27822.09 | Action Mean: -0.20, Std: 0.26
# Episode 306 | Total Reward: 1.16 | Net Worth: 26486.58 | Action Mean: -0.25, Std: 0.24
# Episode 307 | Total Reward: 0.36 | Net Worth: 25182.49 | Action Mean: -0.18, Std: 0.25
# Episode 308 | Total Reward: 0.36 | Net Worth: 17939.08 | Action Mean: -0.24, Std: 0.29
# Episode 309 | Total Reward: 0.36 | Net Worth: 18418.87 | Action Mean: -0.21, Std: 0.26
# Episode 310 | Total Reward: -0.02 | Net Worth: 20372.01 | Action Mean: -0.20, Std: 0.27 | Sharpe Ratio: 2.906
# Episode 311 | Total Reward: 1.31 | Net Worth: 31251.22 | Action Mean: -0.22, Std: 0.25
# Episode 312 | Total Reward: 0.33 | Net Worth: 20752.33 | Action Mean: -0.22, Std: 0.25
# Episode 313 | Total Reward: 0.06 | Net Worth: 20649.89 | Action Mean: -0.26, Std: 0.25
# Episode 314 | Total Reward: 0.97 | Net Worth: 28961.63 | Action Mean: -0.21, Std: 0.24
# Episode 315 | Total Reward: 0.11 | Net Worth: 20205.15 | Action Mean: -0.26, Std: 0.26
# Episode 316 | Total Reward: 1.17 | Net Worth: 30186.63 | Action Mean: -0.25, Std: 0.23
# Episode 317 | Total Reward: 0.84 | Net Worth: 24736.79 | Action Mean: -0.23, Std: 0.24
# Episode 318 | Total Reward: 1.56 | Net Worth: 29560.29 | Action Mean: -0.19, Std: 0.23
# Episode 319 | Total Reward: 0.90 | Net Worth: 28389.91 | Action Mean: -0.24, Std: 0.25
# Episode 320 | Total Reward: 1.08 | Net Worth: 26539.18 | Action Mean: -0.21, Std: 0.23 | Sharpe Ratio: 2.898
# Episode 321 | Total Reward: -0.01 | Net Worth: 19545.86 | Action Mean: -0.22, Std: 0.29
# ...
# Episode 823 | Total Reward: 0.04 | Net Worth: 19477.03 | Action Mean: -0.20, Std: 0.23
# Episode 824 | Total Reward: 0.76 | Net Worth: 24688.88 | Action Mean: -0.18, Std: 0.23
# Episode 825 | Total Reward: 0.10 | Net Worth: 19108.56 | Action Mean: -0.21, Std: 0.26
# Episode 826 | Total Reward: 0.69 | Net Worth: 27969.08 | Action Mean: -0.23, Std: 0.23
# Episode 827 | Total Reward: 0.76 | Net Worth: 26125.90 | Action Mean: -0.24, Std: 0.24
# Episode 828 | Total Reward: -0.25 | Net Worth: 16779.43 | Action Mean: -0.23, Std: 0.24
# Episode 829 | Total Reward: 0.71 | Net Worth: 23543.63 | Action Mean: -0.25, Std: 0.24
# Episode 830 | Total Reward: 0.75 | Net Worth: 24588.33 | Action Mean: -0.20, Std: 0.24 | Sharpe Ratio: 3.174
# Episode 831 | Total Reward: 0.36 | Net Worth: 22138.06 | Action Mean: -0.21, Std: 0.27
# Episode 832 | Total Reward: 0.81 | Net Worth: 24459.91 | Action Mean: -0.20, Std: 0.23
# Episode 833 | Total Reward: 0.62 | Net Worth: 23038.81 | Action Mean: -0.25, Std: 0.25
# Episode 834 | Total Reward: 0.33 | Net Worth: 26232.75 | Action Mean: -0.22, Std: 0.23
# Episode 835 | Total Reward: 0.58 | Net Worth: 27569.12 | Action Mean: -0.21, Std: 0.23
# Episode 836 | Total Reward: 0.02 | Net Worth: 20048.73 | Action Mean: -0.23, Std: 0.25
# Episode 837 | Total Reward: -0.04 | Net Worth: 18521.55 | Action Mean: -0.25, Std: 0.25
# Episode 838 | Total Reward: -0.41 | Net Worth: 16877.28 | Action Mean: -0.19, Std: 0.25
# Episode 839 | Total Reward: 0.12 | Net Worth: 20138.44 | Action Mean: -0.24, Std: 0.26
# Episode 840 | Total Reward: 0.54 | Net Worth: 20988.88 | Action Mean: -0.23, Std: 0.24 | Sharpe Ratio: 3.217
# Episode 841 | Total Reward: 0.70 | Net Worth: 24786.42 | Action Mean: -0.22, Std: 0.22
# Episode 842 | Total Reward: 0.48 | Net Worth: 25651.54 | Action Mean: -0.20, Std: 0.24
# Episode 843 | Total Reward: 0.88 | Net Worth: 26239.14 | Action Mean: -0.23, Std: 0.22
# Episode 844 | Total Reward: 0.73 | Net Worth: 22581.71 | Action Mean: -0.17, Std: 0.24
# Episode 845 | Total Reward: 0.72 | Net Worth: 26188.03 | Action Mean: -0.24, Std: 0.24
# Episode 846 | Total Reward: 0.28 | Net Worth: 16461.54 | Action Mean: -0.25, Std: 0.23
# Episode 847 | Total Reward: -0.10 | Net Worth: 18989.07 | Action Mean: -0.25, Std: 0.25
# Episode 848 | Total Reward: 0.85 | Net Worth: 26567.25 | Action Mean: -0.23, Std: 0.24
# Episode 849 | Total Reward: 0.49 | Net Worth: 27350.20 | Action Mean: -0.22, Std: 0.23
# Episode 850 | Total Reward: -0.36 | Net Worth: 18812.15 | Action Mean: -0.23, Std: 0.26 | Sharpe Ratio: 3.234
# Episode 851 | Total Reward: 0.15 | Net Worth: 18991.90 | Action Mean: -0.18, Std: 0.25
# Episode 852 | Total Reward: 0.20 | Net Worth: 18717.24 | Action Mean: -0.20, Std: 0.26
# Episode 853 | Total Reward: 0.58 | Net Worth: 25472.90 | Action Mean: -0.18, Std: 0.25
# Episode 854 | Total Reward: 1.02 | Net Worth: 25546.70 | Action Mean: -0.23, Std: 0.23
# Episode 855 | Total Reward: -0.14 | Net Worth: 17590.10 | Action Mean: -0.22, Std: 0.22
# Episode 856 | Total Reward: 1.12 | Net Worth: 25968.39 | Action Mean: -0.24, Std: 0.22
# Episode 857 | Total Reward: 1.56 | Net Worth: 32837.87 | Action Mean: -0.22, Std: 0.24
# Episode 858 | Total Reward: 0.31 | Net Worth: 21623.29 | Action Mean: -0.21, Std: 0.21
# Episode 859 | Total Reward: 0.21 | Net Worth: 20546.45 | Action Mean: -0.21, Std: 0.22
# Episode 860 | Total Reward: 0.70 | Net Worth: 21526.01 | Action Mean: -0.24, Std: 0.27 | Sharpe Ratio: 3.209
# Episode 861 | Total Reward: 0.89 | Net Worth: 24653.34 | Action Mean: -0.22, Std: 0.25
# Episode 862 | Total Reward: 0.23 | Net Worth: 18789.59 | Action Mean: -0.21, Std: 0.23
# Episode 863 | Total Reward: -0.36 | Net Worth: 18290.02 | Action Mean: -0.23, Std: 0.24
# Episode 864 | Total Reward: 1.02 | Net Worth: 26323.30 | Action Mean: -0.24, Std: 0.27
# Episode 865 | Total Reward: 0.91 | Net Worth: 25731.89 | Action Mean: -0.22, Std: 0.24
# Episode 866 | Total Reward: 0.38 | Net Worth: 22938.47 | Action Mean: -0.25, Std: 0.22
# Episode 867 | Total Reward: 0.83 | Net Worth: 28836.01 | Action Mean: -0.21, Std: 0.24
# Episode 868 | Total Reward: 0.63 | Net Worth: 23540.21 | Action Mean: -0.24, Std: 0.23
# Episode 869 | Total Reward: 0.14 | Net Worth: 20532.69 | Action Mean: -0.23, Std: 0.26
# Episode 870 | Total Reward: 0.08 | Net Worth: 18413.56 | Action Mean: -0.23, Std: 0.23 | Sharpe Ratio: 3.135
# Episode 871 | Total Reward: 0.48 | Net Worth: 25573.38 | Action Mean: -0.20, Std: 0.24
# Episode 872 | Total Reward: 0.60 | Net Worth: 20532.00 | Action Mean: -0.23, Std: 0.25
# Episode 873 | Total Reward: -0.25 | Net Worth: 18946.41 | Action Mean: -0.26, Std: 0.25
# Episode 874 | Total Reward: -0.04 | Net Worth: 18562.33 | Action Mean: -0.21, Std: 0.24
# Episode 875 | Total Reward: 0.47 | Net Worth: 20676.12 | Action Mean: -0.20, Std: 0.23
# Episode 876 | Total Reward: 0.50 | Net Worth: 25615.98 | Action Mean: -0.21, Std: 0.25
# Episode 877 | Total Reward: 1.25 | Net Worth: 29467.19 | Action Mean: -0.25, Std: 0.25
# Episode 878 | Total Reward: 0.28 | Net Worth: 20522.59 | Action Mean: -0.23, Std: 0.24
# Episode 879 | Total Reward: 0.02 | Net Worth: 18623.38 | Action Mean: -0.21, Std: 0.26
# Episode 880 | Total Reward: 0.86 | Net Worth: 26326.22 | Action Mean: -0.22, Std: 0.22 | Sharpe Ratio: 3.209
# Episode 881 | Total Reward: 0.36 | Net Worth: 22666.72 | Action Mean: -0.20, Std: 0.23
# Episode 882 | Total Reward: 1.11 | Net Worth: 28264.61 | Action Mean: -0.22, Std: 0.23
# Episode 883 | Total Reward: -0.12 | Net Worth: 18038.61 | Action Mean: -0.24, Std: 0.25
# Episode 884 | Total Reward: 0.54 | Net Worth: 20403.64 | Action Mean: -0.21, Std: 0.24
# Episode 885 | Total Reward: 1.86 | Net Worth: 33266.18 | Action Mean: -0.22, Std: 0.25
# Episode 886 | Total Reward: 1.72 | Net Worth: 32270.45 | Action Mean: -0.23, Std: 0.23
# Episode 887 | Total Reward: 1.39 | Net Worth: 30288.04 | Action Mean: -0.26, Std: 0.27
# Episode 888 | Total Reward: 0.29 | Net Worth: 20841.08 | Action Mean: -0.26, Std: 0.21
# Episode 889 | Total Reward: 1.78 | Net Worth: 34042.88 | Action Mean: -0.22, Std: 0.25
# Episode 890 | Total Reward: 0.23 | Net Worth: 20423.30 | Action Mean: -0.25, Std: 0.24 | Sharpe Ratio: 3.029
# Episode 891 | Total Reward: 0.90 | Net Worth: 29320.80 | Action Mean: -0.22, Std: 0.27
# Episode 892 | Total Reward: 0.11 | Net Worth: 19691.22 | Action Mean: -0.24, Std: 0.24
# Episode 893 | Total Reward: -0.21 | Net Worth: 17565.64 | Action Mean: -0.20, Std: 0.25
# Episode 894 | Total Reward: 1.44 | Net Worth: 29873.80 | Action Mean: -0.22, Std: 0.26
# Episode 895 | Total Reward: 1.40 | Net Worth: 28557.74 | Action Mean: -0.20, Std: 0.22
# Episode 896 | Total Reward: 0.44 | Net Worth: 23576.54 | Action Mean: -0.18, Std: 0.18
# Episode 897 | Total Reward: 0.53 | Net Worth: 23035.14 | Action Mean: -0.23, Std: 0.24
# Episode 898 | Total Reward: 1.84 | Net Worth: 30810.18 | Action Mean: -0.21, Std: 0.24
# Episode 899 | Total Reward: 0.15 | Net Worth: 20507.65 | Action Mean: -0.22, Std: 0.24
# Episode 900 | Total Reward: 0.14 | Net Worth: 19961.64 | Action Mean: -0.23, Std: 0.23 | Sharpe Ratio: 3.022
# Episode 901 | Total Reward: 1.35 | Net Worth: 31378.44 | Action Mean: -0.22, Std: 0.27
# Episode 902 | Total Reward: -0.28 | Net Worth: 16787.32 | Action Mean: -0.24, Std: 0.23
# Episode 903 | Total Reward: 0.70 | Net Worth: 23988.04 | Action Mean: -0.19, Std: 0.22
# Episode 904 | Total Reward: -0.18 | Net Worth: 18827.20 | Action Mean: -0.24, Std: 0.24
# Episode 905 | Total Reward: 0.28 | Net Worth: 21847.98 | Action Mean: -0.20, Std: 0.24
# Episode 906 | Total Reward: 0.65 | Net Worth: 23602.90 | Action Mean: -0.20, Std: 0.25
# Episode 907 | Total Reward: 0.54 | Net Worth: 21444.90 | Action Mean: -0.23, Std: 0.23
# Episode 908 | Total Reward: 0.91 | Net Worth: 28763.48 | Action Mean: -0.20, Std: 0.24
# Episode 909 | Total Reward: 0.12 | Net Worth: 19558.14 | Action Mean: -0.20, Std: 0.22
# Episode 910 | Total Reward: 0.65 | Net Worth: 27136.64 | Action Mean: -0.20, Std: 0.23 | Sharpe Ratio: 3.046
# Episode 911 | Total Reward: 0.07 | Net Worth: 20931.18 | Action Mean: -0.21, Std: 0.24
# Episode 912 | Total Reward: 0.66 | Net Worth: 22845.26 | Action Mean: -0.24, Std: 0.23
# Episode 913 | Total Reward: 1.86 | Net Worth: 30906.19 | Action Mean: -0.23, Std: 0.24
# Episode 914 | Total Reward: -0.04 | Net Worth: 18847.17 | Action Mean: -0.23, Std: 0.25
# Episode 915 | Total Reward: -0.04 | Net Worth: 19606.50 | Action Mean: -0.17, Std: 0.24
# Episode 916 | Total Reward: 0.33 | Net Worth: 21402.24 | Action Mean: -0.21, Std: 0.23
# Episode 917 | Total Reward: 0.01 | Net Worth: 20563.11 | Action Mean: -0.24, Std: 0.23
# Episode 918 | Total Reward: 0.37 | Net Worth: 21433.20 | Action Mean: -0.23, Std: 0.23
# Episode 919 | Total Reward: 0.38 | Net Worth: 20801.43 | Action Mean: -0.23, Std: 0.26
# Episode 920 | Total Reward: 0.88 | Net Worth: 26088.86 | Action Mean: -0.23, Std: 0.26 | Sharpe Ratio: 3.084
# Episode 921 | Total Reward: -0.04 | Net Worth: 19151.62 | Action Mean: -0.25, Std: 0.25
# Episode 922 | Total Reward: 0.80 | Net Worth: 23296.04 | Action Mean: -0.24, Std: 0.25
# Episode 923 | Total Reward: -0.01 | Net Worth: 18387.43 | Action Mean: -0.21, Std: 0.22
# Episode 924 | Total Reward: -0.04 | Net Worth: 19144.14 | Action Mean: -0.23, Std: 0.27
# Episode 925 | Total Reward: 0.21 | Net Worth: 17168.06 | Action Mean: -0.24, Std: 0.24
# Episode 926 | Total Reward: 0.40 | Net Worth: 21563.27 | Action Mean: -0.20, Std: 0.24
# Episode 927 | Total Reward: 0.10 | Net Worth: 19077.47 | Action Mean: -0.20, Std: 0.26
# Episode 928 | Total Reward: 0.56 | Net Worth: 23001.15 | Action Mean: -0.22, Std: 0.25
# Episode 929 | Total Reward: 0.72 | Net Worth: 24953.44 | Action Mean: -0.20, Std: 0.24
# Episode 930 | Total Reward: 1.93 | Net Worth: 32207.31 | Action Mean: -0.21, Std: 0.24 | Sharpe Ratio: 3.028
# Episode 931 | Total Reward: -0.03 | Net Worth: 18127.65 | Action Mean: -0.20, Std: 0.26
# Episode 932 | Total Reward: 1.45 | Net Worth: 33067.08 | Action Mean: -0.20, Std: 0.26
# Episode 933 | Total Reward: 0.64 | Net Worth: 21371.63 | Action Mean: -0.24, Std: 0.24
# Episode 934 | Total Reward: 0.02 | Net Worth: 19428.87 | Action Mean: -0.21, Std: 0.25
# Episode 935 | Total Reward: 0.77 | Net Worth: 21321.57 | Action Mean: -0.24, Std: 0.26
# Episode 936 | Total Reward: -0.00 | Net Worth: 19275.04 | Action Mean: -0.21, Std: 0.24
# Episode 937 | Total Reward: 0.31 | Net Worth: 22679.67 | Action Mean: -0.21, Std: 0.23
# Episode 938 | Total Reward: -0.02 | Net Worth: 18977.57 | Action Mean: -0.23, Std: 0.24
# Episode 939 | Total Reward: -0.06 | Net Worth: 18602.86 | Action Mean: -0.23, Std: 0.24
# Episode 940 | Total Reward: 0.56 | Net Worth: 26147.14 | Action Mean: -0.21, Std: 0.25 | Sharpe Ratio: 2.956
# Episode 941 | Total Reward: 0.84 | Net Worth: 23615.76 | Action Mean: -0.21, Std: 0.24
# Episode 942 | Total Reward: 0.79 | Net Worth: 24385.22 | Action Mean: -0.26, Std: 0.19
# Episode 943 | Total Reward: 0.86 | Net Worth: 25844.58 | Action Mean: -0.25, Std: 0.25
# Episode 944 | Total Reward: 0.70 | Net Worth: 25224.24 | Action Mean: -0.21, Std: 0.25
# Episode 945 | Total Reward: 0.63 | Net Worth: 23503.57 | Action Mean: -0.20, Std: 0.20
# Episode 946 | Total Reward: 0.08 | Net Worth: 18188.90 | Action Mean: -0.20, Std: 0.21
# Episode 947 | Total Reward: 0.12 | Net Worth: 19741.90 | Action Mean: -0.23, Std: 0.24
# Episode 948 | Total Reward: 0.59 | Net Worth: 24139.28 | Action Mean: -0.19, Std: 0.24
# Episode 949 | Total Reward: 1.54 | Net Worth: 32261.19 | Action Mean: -0.22, Std: 0.25
# Episode 950 | Total Reward: 1.42 | Net Worth: 30535.45 | Action Mean: -0.20, Std: 0.25 | Sharpe Ratio: 2.951
# Episode 951 | Total Reward: 0.11 | Net Worth: 20252.84 | Action Mean: -0.22, Std: 0.22
# Episode 952 | Total Reward: 1.08 | Net Worth: 29241.22 | Action Mean: -0.23, Std: 0.20
# Episode 953 | Total Reward: 1.08 | Net Worth: 26750.81 | Action Mean: -0.22, Std: 0.23
# Episode 954 | Total Reward: 0.37 | Net Worth: 22687.49 | Action Mean: -0.20, Std: 0.24
# Episode 955 | Total Reward: 1.24 | Net Worth: 32365.67 | Action Mean: -0.24, Std: 0.28
# Episode 956 | Total Reward: 1.08 | Net Worth: 28521.10 | Action Mean: -0.21, Std: 0.25
# Episode 957 | Total Reward: 0.79 | Net Worth: 24727.96 | Action Mean: -0.21, Std: 0.25
# Episode 958 | Total Reward: -0.23 | Net Worth: 17659.88 | Action Mean: -0.22, Std: 0.22
# Episode 959 | Total Reward: 0.05 | Net Worth: 19104.45 | Action Mean: -0.24, Std: 0.24
# Episode 960 | Total Reward: 0.72 | Net Worth: 23124.09 | Action Mean: -0.21, Std: 0.22 | Sharpe Ratio: 2.968
# Episode 961 | Total Reward: -0.10 | Net Worth: 18849.81 | Action Mean: -0.20, Std: 0.23
# Episode 962 | Total Reward: 0.92 | Net Worth: 25691.07 | Action Mean: -0.22, Std: 0.23
# Episode 963 | Total Reward: 1.71 | Net Worth: 30576.56 | Action Mean: -0.20, Std: 0.24
# Episode 964 | Total Reward: 1.61 | Net Worth: 31326.72 | Action Mean: -0.19, Std: 0.27
# Episode 965 | Total Reward: 0.17 | Net Worth: 20254.81 | Action Mean: -0.22, Std: 0.23
# Episode 966 | Total Reward: 0.44 | Net Worth: 23636.61 | Action Mean: -0.24, Std: 0.24
# Episode 967 | Total Reward: -0.17 | Net Worth: 18229.55 | Action Mean: -0.21, Std: 0.26
# Episode 968 | Total Reward: 0.65 | Net Worth: 26401.22 | Action Mean: -0.20, Std: 0.25
# Episode 969 | Total Reward: 0.36 | Net Worth: 20559.22 | Action Mean: -0.21, Std: 0.23
# Episode 970 | Total Reward: -0.02 | Net Worth: 20367.76 | Action Mean: -0.21, Std: 0.23 | Sharpe Ratio: 2.931
# Episode 971 | Total Reward: 0.07 | Net Worth: 17553.63 | Action Mean: -0.21, Std: 0.22
# Episode 972 | Total Reward: -0.27 | Net Worth: 16607.77 | Action Mean: -0.25, Std: 0.23
# Episode 973 | Total Reward: 0.47 | Net Worth: 22596.27 | Action Mean: -0.25, Std: 0.24
# Episode 974 | Total Reward: -0.00 | Net Worth: 18349.19 | Action Mean: -0.22, Std: 0.22
# Episode 975 | Total Reward: 0.03 | Net Worth: 18793.26 | Action Mean: -0.23, Std: 0.23
# Episode 976 | Total Reward: 0.55 | Net Worth: 22881.75 | Action Mean: -0.22, Std: 0.24
# Episode 977 | Total Reward: 1.28 | Net Worth: 26603.10 | Action Mean: -0.24, Std: 0.23
# Episode 978 | Total Reward: -0.04 | Net Worth: 16675.31 | Action Mean: -0.23, Std: 0.25
# Episode 979 | Total Reward: 1.09 | Net Worth: 26721.32 | Action Mean: -0.28, Std: 0.25
# Episode 980 | Total Reward: 0.33 | Net Worth: 20754.28 | Action Mean: -0.23, Std: 0.25 | Sharpe Ratio: 2.856
# Episode 981 | Total Reward: -0.24 | Net Worth: 16882.12 | Action Mean: -0.21, Std: 0.25
# Episode 982 | Total Reward: 0.17 | Net Worth: 21190.40 | Action Mean: -0.20, Std: 0.21
# Episode 983 | Total Reward: 0.66 | Net Worth: 23651.85 | Action Mean: -0.23, Std: 0.19
# Episode 984 | Total Reward: 0.20 | Net Worth: 20301.68 | Action Mean: -0.21, Std: 0.24
# Episode 985 | Total Reward: 0.20 | Net Worth: 22117.25 | Action Mean: -0.24, Std: 0.24
# Episode 986 | Total Reward: 0.07 | Net Worth: 19227.68 | Action Mean: -0.23, Std: 0.21
# Episode 987 | Total Reward: -0.05 | Net Worth: 19239.41 | Action Mean: -0.21, Std: 0.24
# Episode 988 | Total Reward: 0.52 | Net Worth: 21154.49 | Action Mean: -0.21, Std: 0.23
# Episode 989 | Total Reward: 0.31 | Net Worth: 21461.83 | Action Mean: -0.24, Std: 0.25
# Episode 990 | Total Reward: 0.66 | Net Worth: 24004.37 | Action Mean: -0.20, Std: 0.22 | Sharpe Ratio: 2.994
# Episode 991 | Total Reward: 0.91 | Net Worth: 28522.37 | Action Mean: -0.23, Std: 0.23
# Episode 992 | Total Reward: 0.59 | Net Worth: 21765.47 | Action Mean: -0.22, Std: 0.26
# Episode 993 | Total Reward: 1.04 | Net Worth: 25325.41 | Action Mean: -0.21, Std: 0.23
# Episode 994 | Total Reward: 0.03 | Net Worth: 19029.61 | Action Mean: -0.24, Std: 0.23
# Episode 995 | Total Reward: -0.17 | Net Worth: 17902.37 | Action Mean: -0.21, Std: 0.23
# Episode 996 | Total Reward: -0.11 | Net Worth: 16904.62 | Action Mean: -0.22, Std: 0.24
# Episode 997 | Total Reward: -0.02 | Net Worth: 18692.15 | Action Mean: -0.24, Std: 0.22
# Episode 998 | Total Reward: 0.74 | Net Worth: 26374.12 | Action Mean: -0.22, Std: 0.26
# Episode 999 | Total Reward: 0.33 | Net Worth: 21146.89 | Action Mean: -0.24, Std: 0.24
# Episode 1000 | Total Reward: 0.20 | Net Worth: 17879.28 | Action Mean: -0.23, Std: 0.26 | Sharpe Ratio: 2.990
